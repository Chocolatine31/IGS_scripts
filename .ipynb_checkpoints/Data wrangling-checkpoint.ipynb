# %% [markdown]
# # Libraries

# %%
# Import packages
# Performance tracking
import time
from datetime import timedelta
import datetime
import psutil # for memory checks
from psutil._common import bytes2human
import sys
import gc

# Data processing
import pandas as pd
import geopandas as gpd
import os
import shapely                 #needed to set geopandas geometry 
from shapely.wkt import loads  #needed to set geopandas geometry
import rasterio as rio # for rasters
import rasterio.mask
from rasterio import features
import numpy as np
import dask.array as da # Package added to sds2024 environment for chunking and paralllel processing of large files

# Visualisation
import matplotlib.pyplot as plt

# %%
# General Paths
preppedDat_path = 'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/'
rawDat_path = 'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/'
output_path = 'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/'
interimFiles_path = 'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/'
workFiles_path = 'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/work files/'

# %% [markdown]
# # Functions
# ## Poly Rasterization
# ### Iterable function

# %%
# Created 31/01
# Last edit 4/03 adding all_touched arg (True or False)

def polyrast(poly_path, raster_path, logpath, all_touched):
    start = time.perf_counter()
    logstart = f'\nPolyrast Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logstart)
    with open(logpath, 'a') as logfile:
        logfile.writelines([logstart,'\n'])
    # Getting file name for output naming
    filename = os.path.basename(poly_path)
    filename_noExt = os.path.splitext(filename)[0]
    ext = os.path.splitext(filename)[1]
    polyrast_write_path = f'{interimFiles_path}polyrast/{filename_noExt}.tif'
    # Check if file exists
    if not os.path.exists(polyrast_write_path):
        logexist = f'File does not exist: {polyrast_write_path}. \n Processing....'
        print (logexist)
        # Read the reference raster
        logref = f'Read ref raster Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}\n from: {raster_path}'
        print(logref)
        with rio.open(raster_path) as src:
            # Read poly layer
            logrd = f'Read poly Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}\n from: {poly_path}'
            print(logrd)
            vector = gpd.read_file(poly_path)
        
            # Rasterize poly
            #https://pygis.io/docs/e_raster_rasterize.html
            geom = [shapes for shapes in vector.geometry]
            logras = f'Rasterize poly Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
            print(logras)
            # Rasterize vector using the shape and coordinate system of the raster
            rasterized = features.rasterize(geom, out_shape = src.shape, fill = 0, out = None, transform = src.transform, all_touched = all_touched, default_value = 1, dtype = None) # All touched = False --> only pixels fully inside the geom
        
            # Write to file
            logwri = f'Writing rasterized poly to file Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
            print(logwri)
            with rio.open(
            polyrast_write_path, 'w',
            driver='GTiff',
            height=src.shape[0],
            width=src.shape[1],
            count=1,
            dtype=rasterized.dtype,
            crs=src.crs,
            transform=src.transform,
            compress='DEFLATE'
            ) as dst:
                dst.write(rasterized, 1)
        with open(logpath, 'a') as logfile:
            logfile.writelines([logexist,'\n',logref,'\n',logrd,'\n',logras,'\n',logwri,'\n'])
    else:
        logexist = f'File already exists: {polyrast_write_path}. \n Skipping....'
        print (logexist)
        with open(logpath, 'a') as logfile:
            logfile.writelines([logexist,'\n'])

    # Clearing variables for memory
    try:
        del vector
    except:
        print("('vector' var could not be deleted, likely doesn't exist)")
    try:
        del geom
    except:
        print("('geom' var could not be deleted, likely doesn't exist)")
    try:
        del rasterized
    except:
        print("('rasterized' var could not be deleted, likely doesn't exist)")
    try:
        del src
    except:
        print("('src' var could not be deleted, likely doesn't exist)")
    
    logend = f'Polyrast End {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logend)
    end = time.perf_counter()
    elapsed_time = end - start
    # Convert the elapsed time to a timedelta object 
    elapsed_time_str = str(timedelta(seconds=elapsed_time))
    logrun = f'Polyras Code block run in {elapsed_time_str}'
    print(logrun)
    with open(logpath, 'a') as logfile:
        logfile.writelines([logend,'\n', logrun])
    return polyrast_write_path

# %% [markdown]
# ## Memory usage check

# %%
## Check memory usage
logram = f'RAM memory % used:{psutil.virtual_memory()[2]} --- RAM Used (GB):{bytes2human(psutil.virtual_memory()[3])}\nSwap memory used {psutil.swap_memory().percent}% --- {bytes2human(psutil.swap_memory().used)}'
print(logram)
## Code from:
## https://stackoverflow.com/questions/40993626/list-memory-usage-in-ipython-and-jupyter
# These are the usual ipython objects, including this one you are creating
ipython_vars = ['In', 'Out', 'exit', 'quit', 'get_ipython', 'ipython_vars']

# Get a sorted list of the objects and their sizes
print(f'Memory use: {sorted([(x, sys.getsizeof(globals().get(x))) for x in dir() if not x.startswith('_') and x not in sys.modules and x not in ipython_vars], key=lambda x: x[1], reverse=True)[:10]}')
# Out:
# RAM memory % used:51.0 --- RAM Used (GB):8.717692928
# Swap memory used 19.2% --- 9.2G
# Memory use: [('timedelta', 432), ('bytes2human', 160), ('loads', 160), ('open', 160), ('interimFiles_path', 157), ('preppedDat_path', 149), ('rawDat_path', 140), ('output_path', 137), ('logram', 126), ('da', 72)]

# %% [markdown]
# # Layers exploration

# %% [markdown]
# ## Listed Buildings

# %%
poly_path = f'{rawDat_path}Heritage Sites/National_Heritage_List_for_England_NHLE_v02_VIEW_1483746273163179863.gpkg'
poly_df = gpd.read_file(poly_path)
# Out:
# C:\Users\roro_\miniconda3\envs\sds2024_IGS\Lib\site-packages\geopandas\io\file.py:383: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   as_dt = pd.to_datetime(df[k], errors="ignore")
# C:\Users\roro_\miniconda3\envs\sds2024_IGS\Lib\site-packages\geopandas\io\file.py:383: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   as_dt = pd.to_datetime(df[k], errors="ignore")

# %%
poly_df
# Out:
#         ListEntry                                               Name Grade  \
# 0         1021466                      20 and 20A Whitbourne Springs    II
# 1         1021467    TENNIS CORNER FARMHOUSE WITH GRANARY AND STABLE    II
# 2         1021468                                      CHALCOT HOUSE   II*
# 3         1021469                               FIVE LORDS FARMHOUSE    II
# 4         1021470                                      PENLEIGH MILL    II
# ...           ...                                                ...   ...
# 379555    1491659                                Barrow Hall Stables    II
# 379556    1491798            Lamp post outside Corpus Christi Church    II
# 379557    1492041                                Old House Farmhouse    II
# 379558    1492563  Bonham Carter family tomb 10 metres south of t...    II
# 379559    1492564  King family tomb 5 metres south-east of the ch...    II
#
#                         ListDate AmendDate CaptureScale  \
# 0      1987-11-05 00:00:00+00:00       NaT       1:2500
# 1      1987-11-05 00:00:00+00:00       NaT       1:2500
# 2      1968-09-11 00:00:00+00:00       NaT       1:2500
# 3      1987-11-05 00:00:00+00:00       NaT       1:2500
# 4      1987-11-05 00:00:00+00:00       NaT       1:2500
# ...                          ...       ...          ...
# 379555 2024-10-17 14:29:13+00:00       NaT       1:1250
# 379556 2024-10-10 11:44:10+00:00       NaT       1:1250
# 379557 2024-11-20 14:53:40+00:00       NaT       1:1250
# 379558 2005-03-17 00:00:00+00:00       NaT       1:1250
# 379559 2005-03-17 00:00:00+00:00       NaT       1:1250
#
#                                                 hyperlink   area_ha  \
# 0       https://historicengland.org.uk/listing/the-lis...  0.012009
# 1       https://historicengland.org.uk/listing/the-lis...       NaN
# 2       https://historicengland.org.uk/listing/the-lis...       NaN
# 3       https://historicengland.org.uk/listing/the-lis...       NaN
# 4       https://historicengland.org.uk/listing/the-lis...       NaN
# ...                                                   ...       ...
# 379555  https://historicengland.org.uk/listing/the-lis...  0.012289
# 379556  https://historicengland.org.uk/listing/the-lis...  0.000079
# 379557  https://historicengland.org.uk/listing/the-lis...  0.010271
# 379558  https://historicengland.org.uk/listing/the-lis...       NaN
# 379559  https://historicengland.org.uk/listing/the-lis...       NaN
#
#                    NGR   Easting  Northing  \
# 0         ST8338544428  383389.0  144430.0
# 1       ST 82839 50851  382839.0  150851.0
# 2       ST 84294 48824  384294.0  148824.0
# 3       ST 82772 50187  382772.0  150187.0
# 4       ST 85722 50467  385722.0  150467.0
# ...                ...       ...       ...
# 379555    SK3538328397  435373.0  328420.0
# 379556    TQ3037180773  530371.0  180773.0
# 379557    SO4219727746  342197.0  227746.0
# 379558    SU7402720001  474027.0  120001.0
# 379559    SU7403520006  474035.0  120006.0
#
#                                                  geometry
# 0       MULTIPOLYGON (((383396.810 144429.690, 383397....
# 1       MULTIPOLYGON (((382840.250 150850.278, 382839....
# 2       MULTIPOLYGON (((384295.250 148823.278, 384294....
# 3       MULTIPOLYGON (((382773.250 150186.278, 382772....
# 4       MULTIPOLYGON (((385723.250 150466.278, 385722....
# ...                                                   ...
# 379555  MULTIPOLYGON (((435376.710 328387.890, 435381....
# 379556  MULTIPOLYGON (((530371.500 180773.000, 530371....
# 379557  MULTIPOLYGON (((342201.370 227738.290, 342204....
# 379558  MULTIPOLYGON (((474028.357 119999.547, 474027....
# 379559  MULTIPOLYGON (((474036.386 120004.821, 474035....
#
# [379560 rows x 12 columns]

# %%
poly_df['Grade'].unique()
# Out:
# array(['II', 'II*', 'I'], dtype=object)

# %% [markdown]
# ## Airports

# %%
# Check airport data
airports_path = f'{rawDat_path}Airports/hotosm_gbr_airports_points_gpkg.gpkg'
air_gdf = gpd.read_file(airports_path)

# %%
len(air_gdf)
# Out:
# 5701

# %%
air_gdf['aeroway'].unique()
# Out:
# array(['helipad', 'windsock', 'gate', 'holding_position', 'threshold',
#        'parking_position', 'airstrip', 'aerodrome', 'navigationaid',
#        'tower', 'terminal', 'ndb', 'signal_square', 'radar', 'yes',
#        'turn_pad', 'check_in_counter', None, 'control_tower', 'fuel',
#        'heliport', 'arresting_gear', 'check-in desks', 'anemometer',
#        'aircraft_crossing', 'paragliding_takeoff_site'], dtype=object)

# %%
air_gdf.loc[air_gdf['aeroway']=='yes']
# Out:
#                      name name:en aeroway building emergency  \
# 742                Zone C    None     yes     None      None
# 1724               Zone H    None     yes     None      None
# 1726               Zone G    None     yes     None      None
# 1727               Zone F    None     yes     None      None
# 1728               Zone E    None     yes     None      None
# 2958               Zone D    None     yes     None      None
# 4041               Zone A    None     yes     None      None
# 4345  Oversized Baggage 1    None     yes     None      None
#
#      emergency:helipad operator:type capacity:persons addr:full addr:city  \
# 742               None          None             None      None      None
# 1724              None          None             None      None      None
# 1726              None          None             None      None      None
# 1727              None          None             None      None      None
# 1728              None          None             None      None      None
# 2958              None          None             None      None      None
# 4041              None          None             None      None      None
# 4345              None          None             None      None      None
#
#      source      osm_id osm_type                   geometry
# 742    None  4485745431    nodes  POINT (-0.17693 51.16067)
# 1724   None  4485745426    nodes  POINT (-0.17717 51.16149)
# 1726   None  4485745424    nodes  POINT (-0.17709 51.16109)
# 1727   None  4485745425    nodes  POINT (-0.17707 51.16103)
# 1728   None  4485745429    nodes  POINT (-0.17700 51.16088)
# 2958   None  4485745430    nodes  POINT (-0.17699 51.16082)
# 4041   None  4485745433    nodes  POINT (-0.17684 51.16044)
# 4345   None  4485745432    nodes  POINT (-0.17690 51.16061)

# %%
select_air = air_gdf.loc[air_gdf['aeroway'].isin(['helipad',
       'airstrip', 'aerodrome',
       'heliport'
        ])]
select_air
# Out:
#                             name        name:en    aeroway building emergency  \
# 0         Snarehill Hall helipad           None    helipad     None      None
# 19         Cottage Farm Airstrip           None   airstrip     None      None
# 20    Home Farm Private Airstrip           None   airstrip     None      None
# 21           Bonnington Airstrip           None   airstrip     None      None
# 22       Brickwall Farm Airstrip           None  aerodrome     None      None
# ...                          ...            ...        ...      ...       ...
# 5652                        None           None    helipad     None      None
# 5653        Port Adhair Barraigh  Barra Airport  aerodrome     None      None
# 5666                        None           None   airstrip     None      None
# 5679                        None           None    helipad     None      None
# 5685                        None           None   airstrip     None      None
#
#      emergency:helipad operator:type capacity:persons addr:full  \
# 0                 None          None             None      None
# 19                None          None             None      None
# 20                None          None             None      None
# 21                None          None             None      None
# 22                None          None             None      None
# ...                ...           ...              ...       ...
# 5652              None          None             None      None
# 5653              None          None             None      None
# 5666              None          None             None      None
# 5679              None          None             None      None
# 5685              None          None             None      None
#
#           addr:city     source       osm_id osm_type  \
# 0              None       None  12246600491    nodes
# 19         Bloxholm       None   8002936047    nodes
# 20             None       None   8008822001    nodes
# 21             None       None   8010567595    nodes
# 22             None       None   8041513006    nodes
# ...             ...        ...          ...      ...
# 5652           None       None  12444549543    nodes
# 5653  Isle of Barra  wikipedia   1042032788    nodes
# 5666           None       None  12456067269    nodes
# 5679           None       None  12462520943    nodes
# 5685        Saltash       None  12466075858    nodes
#
#                        geometry
# 0      POINT (0.78081 52.41604)
# 19    POINT (-0.42789 53.05560)
# 20    POINT (-1.71953 52.10776)
# 21     POINT (0.94806 51.05891)
# 22     POINT (0.53236 52.09393)
# ...                         ...
# 5652  POINT (-0.26820 51.31729)
# 5653  POINT (-7.44752 57.02501)
# 5666  POINT (-3.72891 50.50611)
# 5679  POINT (-3.05094 53.58453)
# 5685  POINT (-4.21854 50.45595)
#
# [936 rows x 14 columns]

# %%
select_air.to_file(f'{preppedDat_path}Airports/BG_OSM_HDX_Airports.gpkg')

# %% [markdown]
# After checking in QGIS, turns out removing all these classes only removes the big airports. Small countryside airstrips are preserved. --> **use the whole dataset**

# %% [markdown]
# ## GHI x existing solar poly zonal stats

# %%
solstats_path = f'{preppedDat_path}Existing RE/GHI_global_solar_poly_zonalstats.gpkg'
sst_gdf = gpd.read_file(solstats_path)

# %%
sst_gdf['_mean'].describe()
# Out:
# count    2152.000000
# mean     1010.577408
# std        53.235679
# min       820.992526
# 25%       973.875236
# 50%      1007.890083
# 75%      1046.067980
# max      1148.460022
# Name: _mean, dtype: float64

# %%
sst_gdf_renamed = sst_gdf.rename(columns = {'_mean':'GHI'})
color = '#20b9a5' # main color
fig, ax = plt.subplots(figsize=(3,4.5))
sst_gdf_renamed.boxplot(column='GHI', medianprops=dict(linewidth=2, color = 'orange'), boxprops=dict(linestyle='-', linewidth=2, color = color), whiskerprops=dict(linewidth=2, color=color), capprops=dict(linewidth=2, color=color))
ax.set_ylabel('kWh/m²')
plt.savefig(f'{workFiles_path}media/charts/GHI boxplot.png',dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.hist(sst_gdf['_mean'], bins = 200, color = color)
plt.axvline(x=960, color = 'red', linestyle ='--', linewidth=0.8)
ax.set_xlabel('GHI (kWh/m²)')
ax.set_ylabel('Counts')
plt.savefig(f'{workFiles_path}media/charts/GHI histogram.png',dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Layer Prep

# %% [markdown]
# ## General file processing
# ### Slope

# %% [markdown]
# #### Unzipping DTM ASCII files

# %%
# Need to get DTM first
# OS Panorama is only available as an ascii grid for raster files, which is split in thousands of individual zips. Need to extract those for batch processing and merging in QGIS.
# Extract all zips nested in all subfolders: 
# (Thanks Edge AI assistant for this one)
import zipfile

# Specify the directory path
directory_path = 'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/terr50_gagg_gb'

# Function to unzip all files in a directory
def unzip_all_files(directory):
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.zip'):
                file_path = os.path.join(root, file)
                with zipfile.ZipFile(file_path, 'r') as zip_ref:
                    # Extract all contents to the same directory as the zip file
                    zip_ref.extractall(root)
                print(f'Extracted: {file_path}')

# Call the function
unzip_all_files(directory_path)

# %% [markdown]
# #### Scaling values and saving as int16

# %%
start = time.perf_counter()  # performance counter

# Paths
read_path = preppedDat_path + 'OS Terrain 10m slope bicubic deflate float32.tif'
write_path = preppedDat_path + 'OS Terrain 10m slope bicubic deflate scale_100 uint16.tif'

# Open raster file
with rio.open(read_path) as src:
    # Read raster as dask array
    raster_data = da.from_array(src.read(1), chunks=(50))  
    
    # Multiply values by 100 and convert to integers
    processed_data = (raster_data * 100).astype('uint16')  
    
    # Write to file
    with rio.open(
        write_path, 'w',
        driver='GTiff',
        height=src.shape[0],
        width=src.shape[1],
        count=1,
        dtype='uint16',  # Save as 16-bit unsigned integer
        crs=src.crs,
        transform=src.transform,
        compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

end = time.perf_counter()  # performance counter
elapsed_time = end - start
# Convert the elapsed time to a timedelta object
elapsed_time_str = str(timedelta(seconds=elapsed_time))
print(f'Code block run in {elapsed_time_str}')
del raster_data
del processed_data
del src
del dst
gc.collect()
# Out:
# C:\Users\roro_\miniconda3\envs\sds2024_IGS\Lib\site-packages\dask\array\chunk.py:278: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# Code block run in 0:40:10.188348
# 0

# %% [markdown]
# There are bugs in the output, for some reason. Working with float32 for now.

# %% [markdown]
# ## Extracting LULC categories (raster)

# %% [markdown]
# ### Woodland

# %%
# Woodland layer
start = time.perf_counter() # performance counter
# Extracting Woodland from LULC
# Paths
lulc_path = preppedDat_path+'UKCEH_LC_2023_10m.tif' # LULC data 
write_path = preppedDat_path+'UKCEH_10m_woodland.tif' # output file

# Open the raster file
with rio.open(lulc_path) as src:
    # Read the raster data as a dask array
    raster_data = da.from_array(src.read(1), chunks=(100, 100)) #NB: using dask to split file in chunks for multithreaded processing, as image was too big to be read directly
    
    # Perform operations on the dask array
    mask = np.isin(raster_data, [1, 2]) # Select broadleaved (1) and coniferous (2) woodland pixels
    processed_data = np.where(mask, 1, 0).astype('uint8') #Pixels out of mask set to 0, inside mask set to 1. Result as unsigned int8 data to reduce file size & memory usage (not sure it'll make a difference as original file is already 8-bit unsigned. Does seem to fix my out-of-memory issues)

    with rio.open(
    write_path, 'w',
    driver='GTiff',
    height=src.shape[0],
    width=src.shape[1],
    count=1,
    dtype='uint8',
    crs=src.crs,
    transform=src.transform,
    compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

end = time.perf_counter() # performance counter
elapsed_time = end - start
# Convert the elapsed time to a timedelta object 
elapsed_time_str = str(timedelta(seconds=elapsed_time))
print(f'Code block run in {elapsed_time_str}')
# Out:
# Code block run in 0:19:49.913242

# %% [markdown]
# ### Water

# %%
# Water LAYER
start = time.perf_counter() # performance counter
# Extracting water from LULC
# Paths
lulc_path = preppedDat_path+'UKCEH_LC_2023_10m.tif' # LULC data 
write_path = preppedDat_path+'UKCEH_10m_water.tif' # output file

# Open the raster file
with rio.open(lulc_path) as src:
    # Read the raster data as a dask array
    raster_data = da.from_array(src.read(1), chunks=(100, 100)) #NB: using dask to split file in chunks for multithreaded processing, as image was too big to be read directly
    
    # Perform operations on the dask array
    mask = da.isin(raster_data, [13, 14]) # Select saltwater (13) and freshwater (14) pixels
    processed_data = da.where(mask, 1, 0).astype('uint8') #Pixels out of mask set to 0, inside mask set to 1. Result as unsigned int8 data to reduce file size & memory usage (not sure it'll make a difference as original file is already 8-bit unsigned)
  
    # Write the processed data back to a new raster file
    with rio.open(write_path, 'w', **src.profile) as dst:
        dst.write(processed_data.compute(), 1)

end = time.perf_counter() # performance counter
elapsed_time = end - start
# Convert the elapsed time to a timedelta object 
elapsed_time_str = str(timedelta(seconds=elapsed_time))
print(f'Code block run in {elapsed_time_str}')
# Out:
# Code block run in 0:19:20.002825

# %%
del start
gc.collect()
# Out:
# 1823576

# %% [markdown]
# ### Urban

# %%
# Urban layer
start = time.perf_counter() # performance counter
# Extracting Urban from LULC
# Paths
lulc_path = preppedDat_path+'UKCEH_LC_2023_10m.tif' # LULC data 
write_path = preppedDat_path+'UKCEH_10m_urban.tif' # output file

# Open the raster file
with rio.open(lulc_path) as src:
    # Read the raster data as a dask array
    raster_data = da.from_array(src.read(1), chunks=(100, 100)) #NB: using dask to split file in chunks for multithreaded processing, as image was too big to be read directly
    
    # Perform operations on the dask array
    mask = np.isin(raster_data, [20, 21]) # Select urban (20) and suburban (21) pixels
    processed_data = np.where(mask, 1, 0).astype('uint8') #Pixels out of mask set to 0, inside mask set to 1. Result as unsigned int8 data to reduce file size & memory usage (not sure it'll make a difference as original file is already 8-bit unsigned. Does seem to fix my out-of-memory issues)

    with rio.open(
    write_path, 'w',
    driver='GTiff',
    height=src.shape[0],
    width=src.shape[1],
    count=1,
    dtype='uint8',
    crs=src.crs,
    transform=src.transform,
    compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

end = time.perf_counter() # performance counter
elapsed_time = end - start
# Convert the elapsed time to a timedelta object 
elapsed_time_str = str(timedelta(seconds=elapsed_time))
print(f'Code block run in {elapsed_time_str}')
# Out:
# Code block run in 0:18:17.046125

# %% [markdown]
# ## Urban remove small areas from poly

# %%
gdf = gpd.read_file(f'{preppedDat_path}Land Cover/UKCEH_10m_Urban.gpkg')

# %%
gdf
# Out:
#          DN                                           geometry  Area_(m2)
# 0         1  POLYGON ((460690.000 1219710.000, 460690.000 1...      100.0
# 1         1  POLYGON ((460640.000 1219690.000, 460640.000 1...      100.0
# 2         1  POLYGON ((463140.000 1216740.000, 463140.000 1...    12200.0
# 3         1  POLYGON ((462960.000 1216640.000, 462960.000 1...     7700.0
# 4         1  POLYGON ((465850.000 1216440.000, 465850.000 1...      100.0
# ...      ..                                                ...        ...
# 1083626   1  POLYGON ((88270.000 8020.000, 88270.000 8000.0...      500.0
# 1083627   1  POLYGON ((87610.000 8130.000, 87610.000 8120.0...    12000.0
# 1083628   1  POLYGON ((88270.000 7990.000, 88270.000 7980.0...      100.0
# 1083629   1  POLYGON ((87790.000 7840.000, 87790.000 7830.0...      100.0
# 1083630   1  POLYGON ((87700.000 7780.000, 87700.000 7770.0...      100.0
#
# [1083631 rows x 3 columns]

# %%
# Calculate Area column
gdf['Area_(m2)']=gdf['geometry'].area # calculates area (nb: Geopandas calculations are planimetric, not ellipsoidal)

# %%
# Save to file
gdf.to_file(f'{preppedDat_path}Land Cover/UKCEH_10m_Urban.gpkg', overwrite = 'yes')

# %%
# Select only areas above 2ha
gdf_2ha = gdf.loc[gdf['Area_(m2)']>20000]
gdf_2ha
# Out:
#          DN                                           geometry  Area_(m2)
# 29        1  POLYGON ((466740.000 1215580.000, 466740.000 1...    27100.0
# 84        1  POLYGON ((464490.000 1213490.000, 464490.000 1...    60300.0
# 177       1  POLYGON ((462160.000 1209580.000, 462160.000 1...    44600.0
# 195       1  POLYGON ((463400.000 1209240.000, 463400.000 1...    23800.0
# 213       1  POLYGON ((462290.000 1209080.000, 462290.000 1...    39600.0
# ...      ..                                                ...        ...
# 1083521   1  POLYGON ((91130.000 11130.000, 91130.000 11120...    21300.0
# 1083556   1  POLYGON ((89740.000 10490.000, 89740.000 10470...    22900.0
# 1083563   1  POLYGON ((90860.000 11440.000, 90860.000 11420...   441300.0
# 1083579   1  POLYGON ((91470.000 10520.000, 91470.000 10510...   105400.0
# 1083625   1  POLYGON ((88000.000 8510.000, 88000.000 8500.0...   108500.0
#
# [48774 rows x 3 columns]

# %%
# Save to file
gdf_2ha.to_file(f'{preppedDat_path}Land Cover/UKCEH_10m_Urban_2ha.gpkg', overwrite = 'yes')

# %% [markdown]
# ## Rasterizations

# %% [markdown]
# ### Protected Areas

# %% [markdown]
# #### UNEP-WCMC

# %%
# Checking data
pa_df0 = gpd.read_file(f'{rawDat_path}UNEP-WCMC and IUCN (2024) Protected Areas/WDPA_WDOECM_Mar2024_Public_GBR_shp_0/WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons.shp')
pa_df1 = gpd.read_file(f'{rawDat_path}UNEP-WCMC and IUCN (2024) Protected Areas/WDPA_WDOECM_Mar2024_Public_GBR_shp_1/WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons.shp')
pa_df2 = gpd.read_file(f'{rawDat_path}UNEP-WCMC and IUCN (2024) Protected Areas/WDPA_WDOECM_Mar2024_Public_GBR_shp_2/WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons.shp')

# %%
UNEP_df = gpd.read_file(f'{preppedDat_path}UNEP-WCMC_Protected_Areas_2024_merged.gpkg')
JNCC_df = gpd.read_file(f'{preppedDat_path}JNCC_Ramsar_SPA.gpkg')

# %%
UNEP_df
# Out:
#          WDPAID WDPA_PID PA_DEF                                NAME  \
# 0         959.0      959      1                       Lake District
# 1         960.0      960      1                           Snowdonia
# 2         961.0      961      1                     Yorkshire Dales
# 3         962.0      962      1                    North York Moors
# 4         963.0      963      1                       Peak District
# ...         ...      ...    ...                                 ...
# 10897  170072.0   170072      1                           River Axe
# 10898  170073.0   170073      1                         River Barle
# 10899  170074.0   170074      1                        River Borgie
# 10900  170076.0   170076      1  River Dee (Parton To Crossmichael)
# 10901  170077.0   170077      1       River Derwent And Tributaries
#
#                                 ORIG_NAME  \
# 0                           Lake District
# 1                               Snowdonia
# 2                         Yorkshire Dales
# 3                        North York Moors
# 4                           Peak District
# ...                                   ...
# 10897                           River Axe
# 10898                         River Barle
# 10899                        River Borgie
# 10900  River Dee (Parton To Crossmichael)
# 10901       River Derwent And Tributaries
#
#                                           DESIG  \
# 0                                 National Park
# 1                                 National Park
# 2                                 National Park
# 3                                 National Park
# 4                                 National Park
# ...                                         ...
# 10897  Site Of Special Scientific Interest (Uk)
# 10898  Site Of Special Scientific Interest (Uk)
# 10899  Site Of Special Scientific Interest (Uk)
# 10900  Site Of Special Scientific Interest (Uk)
# 10901  Site Of Special Scientific Interest (Uk)
#
#                                       DESIG_ENG DESIG_TYPE IUCN_CAT  \
# 0                                 National Park   National        V
# 1                                 National Park   National        V
# 2                                 National Park   National        V
# 3                                 National Park   National        V
# 4                                 National Park   National        V
# ...                                         ...        ...      ...
# 10897  Site Of Special Scientific Interest (Gb)   National       IV
# 10898  Site Of Special Scientific Interest (Gb)   National       IV
# 10899  Site Of Special Scientific Interest (Gb)   National       IV
# 10900  Site Of Special Scientific Interest (Gb)   National       IV
# 10901  Site Of Special Scientific Interest (Gb)   National       IV
#
#              INT_CRIT  ...           VERIF  METADATAID       SUB_LOC  \
# 0      Not Applicable  ...  State Verified        1839  Not Reported
# 1      Not Applicable  ...  State Verified        1839  Not Reported
# 2      Not Applicable  ...  State Verified        1839  Not Reported
# 3      Not Applicable  ...  State Verified        1839  Not Reported
# 4      Not Applicable  ...  State Verified        1839  Not Reported
# ...               ...  ...             ...         ...           ...
# 10897  Not Applicable  ...  State Verified        1839  Not Reported
# 10898  Not Applicable  ...  State Verified        1839  Not Reported
# 10899  Not Applicable  ...  State Verified        1839  Not Reported
# 10900  Not Applicable  ...  State Verified        1839  Not Reported
# 10901  Not Applicable  ...  State Verified        1839  Not Reported
#
#        PARENT_ISO  ISO3       SUPP_INFO        CONS_OBJ  \
# 0             GBR   GBR  Not Applicable  Not Applicable
# 1             GBR   GBR  Not Applicable  Not Applicable
# 2             GBR   GBR  Not Applicable  Not Applicable
# 3             GBR   GBR  Not Applicable  Not Applicable
# 4             GBR   GBR  Not Applicable  Not Applicable
# ...           ...   ...             ...             ...
# 10897         GBR   GBR  Not Applicable  Not Applicable
# 10898         GBR   GBR  Not Applicable  Not Applicable
# 10899         GBR   GBR  Not Applicable  Not Applicable
# 10900         GBR   GBR  Not Applicable  Not Applicable
# 10901         GBR   GBR  Not Applicable  Not Applicable
#
#                                              layer  \
# 0      WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons
# 1      WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons
# 2      WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons
# 3      WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons
# 4      WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons
# ...                                            ...
# 10897  WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons
# 10898  WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons
# 10899  WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons
# 10900  WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons
# 10901  WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons
#
#                                                     path  \
# 0      C:/Users/roro_/Documents/University/UG year 3/...
# 1      C:/Users/roro_/Documents/University/UG year 3/...
# 2      C:/Users/roro_/Documents/University/UG year 3/...
# 3      C:/Users/roro_/Documents/University/UG year 3/...
# 4      C:/Users/roro_/Documents/University/UG year 3/...
# ...                                                  ...
# 10897  C:/Users/roro_/Documents/University/UG year 3/...
# 10898  C:/Users/roro_/Documents/University/UG year 3/...
# 10899  C:/Users/roro_/Documents/University/UG year 3/...
# 10900  C:/Users/roro_/Documents/University/UG year 3/...
# 10901  C:/Users/roro_/Documents/University/UG year 3/...
#
#                                                 geometry
# 0      MULTIPOLYGON (((-2.86963 54.19145, -2.87077 54...
# 1      MULTIPOLYGON (((-3.88655 53.27407, -3.88651 53...
# 2      MULTIPOLYGON (((-2.27162 54.06538, -2.27163 54...
# 3      MULTIPOLYGON (((-1.30412 54.32533, -1.30419 54...
# 4      MULTIPOLYGON (((-1.85357 53.29334, -1.85395 53...
# ...                                                  ...
# 10897  MULTIPOLYGON (((-2.96084 50.81692, -2.96083 50...
# 10898  MULTIPOLYGON (((-3.82724 51.16635, -3.82717 51...
# 10899  MULTIPOLYGON (((-4.26209 58.52818, -4.26246 58...
# 10900  MULTIPOLYGON (((-4.05856 55.01027, -4.05851 55...
# 10901  MULTIPOLYGON (((-2.98860 54.66371, -2.98858 54...
#
# [10902 rows x 33 columns]

# %%
UNEP_df['IUCN_CAT'].unique()
# Out:
# array(['V', 'Not Assigned', 'II', 'IV', 'III', 'Not Applicable',
#        'Not Reported', 'Ia', 'VI'], dtype=object)

# %%
UNEP_df['DESIG'].unique()
# Out:
# array(['National Park', 'National Nature Reserve',
#        'UNESCO-MAB Biosphere Reserve', 'Heritage Coast',
#        'World Heritage Site (natural or mixed)', 'National Scenic Area',
#        'Area Of Outstanding Natural Beauty', 'Regional Park',
#        'Ramsar Site, Wetland of International Importance',
#        'Area Of Special Scientific Interest (Ni)', 'Local Nature Reserve',
#        'Site Of Special Scientific Interest (Uk)',
#        'Area Of Outstanding Natural Beauty (Ni)',
#        'Special Protection Area', 'Marine Protected Area (OSPAR)',
#        'Marine Conservation Zone', 'Voluntary Reserve',
#        'Nature Conservation Marine Protected Area', 'Nature Reserve',
#        'Wildland reserve',
#        'Demonstration And Research Marine Protected Area',
#        'Marine Protected Area'], dtype=object)

# %%
# Get all unique values of DESIG for each IUCN_CAT and convert to strings
unique_desig_per_iucn = UNEP_df.groupby('IUCN_CAT')['DESIG'].apply(lambda x: ', '.join(x.unique())) # forcing it to save as strings as the numpy array originally returned was not saving well into csv (truncated list)
# Save to file for easy retrieval
unique_desig_per_iucn.to_csv(f'{preppedDat_path}UNEP-WCMC_Protected_Areas_2024_merged_designations.csv', header=True)
# Display the result
print(unique_desig_per_iucn)
# Out:
# IUCN_CAT
# II                          National Nature Reserve, Nature Reserve
# III               National Nature Reserve, Site Of Special Scien...
# IV                National Nature Reserve, Area Of Special Scien...
# Ia                Ramsar Site, Wetland of International Importan...
# Not Applicable    UNESCO-MAB Biosphere Reserve, World Heritage S...
# Not Assigned      National Nature Reserve, Heritage Coast, Natio...
# Not Reported      Ramsar Site, Wetland of International Importan...
# V                 National Park, Heritage Coast, Area Of Outstan...
# VI                                                   Nature Reserve
# Name: DESIG, dtype: object

# %%
# Checking differently because the list in the csv appeared incomplete
for i in UNEP_df['IUCN_CAT'].unique():
    desigs = UNEP_df.loc[UNEP_df['IUCN_CAT']== i]['DESIG'].unique()
    print(f'Cat: {i}, {desigs}')
# Out:
# Cat: V, ['National Park' 'Heritage Coast' 'Area Of Outstanding Natural Beauty'
#  'Area Of Outstanding Natural Beauty (Ni)' 'Nature Reserve']
# Cat: Not Assigned, ['National Nature Reserve' 'Heritage Coast' 'National Scenic Area'
#  'Regional Park' 'Marine Protected Area (OSPAR)']
# Cat: II, ['National Nature Reserve' 'Nature Reserve']
# Cat: IV, ['National Nature Reserve' 'Area Of Special Scientific Interest (Ni)'
#  'Local Nature Reserve' 'Site Of Special Scientific Interest (Uk)'
#  'Nature Conservation Marine Protected Area' 'Nature Reserve'
#  'Wildland reserve' 'National Scenic Area' 'Marine Protected Area (OSPAR)']
# Cat: III, ['National Nature Reserve' 'Site Of Special Scientific Interest (Uk)'
#  'Nature Reserve']
# Cat: Not Applicable, ['UNESCO-MAB Biosphere Reserve' 'World Heritage Site (natural or mixed)']
# Cat: Not Reported, ['Ramsar Site, Wetland of International Importance' 'Local Nature Reserve'
#  'Special Protection Area' 'Marine Protected Area (OSPAR)'
#  'Marine Conservation Zone' 'Voluntary Reserve'
#  'Nature Conservation Marine Protected Area'
#  'Demonstration And Research Marine Protected Area'
#  'Marine Protected Area']
# Cat: Ia, ['Ramsar Site, Wetland of International Importance' 'Nature Reserve']
# Cat: VI, ['Nature Reserve']

# %%
UNEP_df.loc[UNEP_df['DESIG'].str.contains('Special Protection Area', case=False, na=False)]
# Out:
#            WDPAID   WDPA_PID PA_DEF                           NAME  \
# 5140  555541782.0  555541782      1  Teesmouth and Cleveland Coast
# 7264  555703761.0  555703761      1        Solent and Dorset Coast
#
#                           ORIG_NAME                    DESIG  \
# 5140  Teesmouth and Cleveland Coast  Special Protection Area
# 7264        Solent and Dorset Coast  Special Protection Area
#
#                                       DESIG_ENG DESIG_TYPE      IUCN_CAT  \
# 5140  Special Protection Area (Birds Directive)   Regional  Not Reported
# 7264  Special Protection Area (Birds Directive)   Regional  Not Reported
#
#             INT_CRIT  ...           VERIF  METADATAID  SUB_LOC  PARENT_ISO  \
# 5140  Not Applicable  ...  State Verified        1994   GB-ENG         GBR
# 7264  Not Applicable  ...  State Verified        1994   GB-ENG         GBR
#
#       ISO3       SUPP_INFO        CONS_OBJ  \
# 5140   GBR  Not Applicable  Not Applicable
# 7264   GBR  Not Applicable  Not Applicable
#
#                                             layer  \
# 5140  WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons
# 7264  WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons
#
#                                                    path  \
# 5140  C:/Users/roro_/Documents/University/UG year 3/...
# 7264  C:/Users/roro_/Documents/University/UG year 3/...
#
#                                                geometry
# 5140  MULTIPOLYGON (((-1.23370 54.76956, -1.20077 54...
# 7264  MULTIPOLYGON (((-1.16710 50.85258, -1.16710 50...
#
# [2 rows x 33 columns]

# %%
# Checking number of Ramsar sites
len(UNEP_df.loc[UNEP_df['DESIG'].str.contains('Ramsar', case=False, na=False)])
# We get 151 sites
# Out:
# 151

# %%
# Checking for JNCC df Ramsar (Ramsar sites are the only ones with Status == designated, the rest is SPA)
len(JNCC_df.loc[JNCC_df['STATUS']=='Designated'])
# We get 152 sites
# Out:
# 152

# %%
# Checking number of SPA
len(UNEP_df.loc[UNEP_df['DESIG'].str.contains('Special Protection Area', case=False, na=False)])
# We get 2 sites
# Out:
# 2

# %%
# Checking for JNCC df SPA (Ramsar sites are the only ones with Status == designated, the rest is SPA)
len(JNCC_df.loc[JNCC_df['STATUS']!='Designated'])
# We get 270 sites
# Out:
# 270

# %%
# Other checks
UNEP_df.loc[UNEP_df['DESIG_ENG'] == 'National Nature Reserve, Wetland of International Importance, Site of Community Importance, Special Protection Area Site of Community Importance']

# %%
pa_df.loc[pa_df['DESIG'] == 'Special Protection Area']
# Out:
#            WDPAID   WDPA_PID PA_DEF                           NAME  \
# 5140  555541782.0  555541782      1  Teesmouth and Cleveland Coast
# 7264  555703761.0  555703761      1        Solent and Dorset Coast
#
#                           ORIG_NAME                    DESIG  \
# 5140  Teesmouth and Cleveland Coast  Special Protection Area
# 7264        Solent and Dorset Coast  Special Protection Area
#
#                                       DESIG_ENG DESIG_TYPE      IUCN_CAT  \
# 5140  Special Protection Area (Birds Directive)   Regional  Not Reported
# 7264  Special Protection Area (Birds Directive)   Regional  Not Reported
#
#             INT_CRIT  ...           VERIF  METADATAID  SUB_LOC  PARENT_ISO  \
# 5140  Not Applicable  ...  State Verified        1994   GB-ENG         GBR
# 7264  Not Applicable  ...  State Verified        1994   GB-ENG         GBR
#
#       ISO3       SUPP_INFO        CONS_OBJ  \
# 5140   GBR  Not Applicable  Not Applicable
# 7264   GBR  Not Applicable  Not Applicable
#
#                                             layer  \
# 5140  WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons
# 7264  WDPA_WDOECM_Mar2024_Public_GBR_shp-polygons
#
#                                                    path  \
# 5140  C:/Users/roro_/Documents/University/UG year 3/...
# 7264  C:/Users/roro_/Documents/University/UG year 3/...
#
#                                                geometry
# 5140  MULTIPOLYGON (((-1.23370 54.76956, -1.20077 54...
# 7264  MULTIPOLYGON (((-1.16710 50.85258, -1.16710 50...
#
# [2 rows x 33 columns]

# %% [markdown]
# ##### Rasterizing poly
# Polyrast doesn't work with UNEP geometries. Creating prepped geometries here and rasterizing in QGIS (GDAL "rasterize (overwrite with fixed value)" with pre-generated constant raster of correct dimensions. Only works with a temp layer then exporting to file. Doesn't work when saving straight to file, for some reason.)

# %%
# Setting categories
cat1 = UNEP_df.loc[(UNEP_df['IUCN_CAT'].isin(['Ia','II','III'])) & (~UNEP_df['DESIG'].str.contains('Ramsar', case=False, na=False))] # tilde inverts the boolean series
cat2 = UNEP_df.loc[(UNEP_df['IUCN_CAT'].isin(['IV','Not Applicable''Not Assigned', 'Not Reported'])) & (~UNEP_df['DESIG'].str.contains('Special Protection Area', case=False, na=False))]
cat3 = UNEP_df.loc[(UNEP_df['IUCN_CAT'].isin(['V'])) & (~UNEP_df['DESIG'].str.contains('Area Of Outstanding Natural Beauty', case=False, na=False))]
cat4 = UNEP_df.loc[(UNEP_df['IUCN_CAT'].isin(['VI'])) | (UNEP_df['DESIG'].str.contains('Area Of Outstanding Natural Beauty', case=False, na=False))]
for i,j in enumerate([cat1, cat2, cat3, cat4]):
    j.to_file(f'{preppedDat_path}UNEP-WCMC_Protected_Areas_2024_merged_cat{i}.gpkg')

# %% [markdown]
# ##### Merging rasters

# %%
write_path = f'{preppedDat_path}UNEP-WCMC_Protected_Areas_2024_merged.tif'
path1 = f'{interimFiles_path}WDPA_WDOECM_Mar2024_Public_GBR_shp_0.tif'
path2 = f'{interimFiles_path}WDPA_WDOECM_Mar2024_Public_GBR_shp_1.tif'
path3 = f'{interimFiles_path}WDPA_WDOECM_Mar2024_Public_GBR_shp_2.tif'

with rio.open(path1) as src_1:
    dask_ar_1 = da.from_array(src_1.read(1), chunks= 100)

with rio.open(path2) as src_2:
    dask_ar_2 = da.from_array(src_2.read(1), chunks= 100)

    # Merging 1-2
    logmsk = f'Merge 1-2\n Mask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logmsk)
    mask = dask_ar_1 > 0 # Make a boolean array out of non-null raster pixels
    logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logdifst)
    processed_data = da.where(mask, 1, dask_ar_2) #Pixels in mask set to 1        
    logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge 1-2 complete.'
    print(logdif)
    # Merging result - 3
    with rio.open(path3) as src_3:
        dask_ar_3 = da.from_array(src_3.read(1), chunks= 100)
    logmsk = f'Merge result-3\n Mask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logmsk)
    mask = processed_data > 0 # Make a boolean array out of non-null raster pixels
    logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logdifst)
    processed_data = da.where(mask, 1, dask_ar_3) #Pixels in mask set to 1       
    logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge result-3 complete.'
    print(logdif)
    # Write result to file
    with rio.open(
        write_path, 'w',
        driver='GTiff',
        height=processed_data.shape[0],
        width=processed_data.shape[1],
        count=1,
        dtype=processed_data.dtype,
        crs=src_1.crs,
        transform=src_1.transform,
        compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

    logwri = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge final result written to file.'
    print(logwri)
# Out:
# Merge 1-2
#  Mask creation Start 2025-02-05 14:01:22
# Merge Start 2025-02-05 14:01:22
# 2025-02-05 14:01:22 - Merge 1-2 complete.
# Merge result-3
#  Mask creation Start 2025-02-05 14:02:06
# Merge Start 2025-02-05 14:02:06
# 2025-02-05 14:02:06 - Merge result-3 complete.
# 2025-02-05 14:17:18 - Merge final result written to file.

# %% [markdown]
# #### Merge all UNEP categories (for PAstats)

# %% [markdown]
# Like for agri, QGIS is giving out weird results, and I can't open all 4 layers at once in a script
# --> Doing the laborious process here
# Tried writing a loop but for some reason it's bugging when trying to write to file. Not time saving enough to warrant debugging, I'll just copy the working script and change inputs.

# %%
# Merge 1-2
write_path = f'{preppedDat_path}PAs/UNEP-WCMC_Protected_Areas_2024_merged_cat1-2.tif' # Result file
path1 = f'{preppedDat_path}PAs/UNEP-WCMC_Protected_Areas_2024_merged_cat1.tif' #top layer
path2 = f'{preppedDat_path}PAs/UNEP-WCMC_Protected_Areas_2024_merged_cat2.tif' #bottom layer

with rio.open(path1) as src_1:
    dask_ar_1 = da.from_array(src_1.read(1), chunks= 100)

with rio.open(path2) as src_2:
    dask_ar_2 = da.from_array(src_2.read(1), chunks= 100)

    # Merging 2-1
    logmsk = f'Merge 1-2\nMask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logmsk)
    mask = dask_ar_1 > 0 # Make a boolean mask out of non-null raster pixels (top layer)
    logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logdifst)
    processed_data = da.where(mask, dask_ar_1, dask_ar_2*2) 
    logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge 1-2 complete.'
    print(logdif)
    
    # Write result to file
    with rio.open(
        write_path, 'w',
        driver='GTiff',
        height=processed_data.shape[0],
        width=processed_data.shape[1],
        count=1,
        dtype=processed_data.dtype,
        crs=src_1.crs,
        transform=src_1.transform,
        compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

    logwri = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge final result written to file.'
    print(logwri)
# Out:
# Merge 1-2
# Mask creation Start 2025-03-14 17:09:50
# Merge Start 2025-03-14 17:09:50
# 2025-03-14 17:09:52 - Merge 1-2 complete.
# 2025-03-14 17:19:48 - Merge final result written to file.

# %%
layers = [3,4]
layers[0]
# Out:
# 3

# %%
# Merge 3-4
layers = [3,4] # 2 layers to be merged, top first
write_path = f'{preppedDat_path}PAs/UNEP-WCMC_Protected_Areas_2024_merged_cat{layers[0]}-{layers[1]}.tif' # Result file
path1 = f'{preppedDat_path}PAs/UNEP-WCMC_Protected_Areas_2024_merged_cat{layers[0]}.tif' #top layer
path2 = f'{preppedDat_path}PAs/UNEP-WCMC_Protected_Areas_2024_merged_cat{layers[1]}.tif' #bottom layer

with rio.open(path1) as src_1:
    dask_ar_1 = da.from_array(src_1.read(1), chunks= 100)

with rio.open(path2) as src_2:
    dask_ar_2 = da.from_array(src_2.read(1), chunks= 100)

    # Merging 2-1
    logmsk = f'Merge {layers[0]}-{layers[1]}\nMask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logmsk)
    mask = dask_ar_1 > 0 # Make a boolean mask out of non-null raster pixels (top layer)
    logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logdifst)
    processed_data = da.where(mask, dask_ar_1*layers[0], dask_ar_2*layers[1]) 
    logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge {layers[0]}-{layers[1]} complete.'
    print(logdif)
    
    # Write result to file
    with rio.open(
        write_path, 'w',
        driver='GTiff',
        height=processed_data.shape[0],
        width=processed_data.shape[1],
        count=1,
        dtype=processed_data.dtype,
        crs=src_1.crs,
        transform=src_1.transform,
        compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

    logwri = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge final result written to file.'
    print(logwri)
# Out:
# Merge 1-2
# Mask creation Start 2025-03-14 17:22:23
# Merge Start 2025-03-14 17:22:24
# 2025-03-14 17:22:24 - Merge 1-2 complete.
# 2025-03-14 17:33:27 - Merge final result written to file.

# %%
# Merge results
write_path = f'{preppedDat_path}PAs/UNEP-WCMC_Protected_Areas_2024_merged_categorized.tif' # Result file
path1 = f'{preppedDat_path}PAs/UNEP-WCMC_Protected_Areas_2024_merged_cat1-2.tif' #top layer
path2 = f'{preppedDat_path}PAs/UNEP-WCMC_Protected_Areas_2024_merged_cat3-4.tif' #bottom layer

with rio.open(path1) as src_1:
    dask_ar_1 = da.from_array(src_1.read(1), chunks= 100)

with rio.open(path2) as src_2:
    dask_ar_2 = da.from_array(src_2.read(1), chunks= 100)

    # Merging 2-1
    logmsk = f'Merge results\nMask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logmsk)
    mask = dask_ar_1 > 0 # Make a boolean mask out of non-null raster pixels (top layer)
    logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logdifst)
    processed_data = da.where(mask, dask_ar_1, dask_ar_2) 
    logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge results complete.'
    print(logdif)
    
    # Write result to file
    with rio.open(
        write_path, 'w',
        driver='GTiff',
        height=processed_data.shape[0],
        width=processed_data.shape[1],
        count=1,
        dtype=processed_data.dtype,
        crs=src_1.crs,
        transform=src_1.transform,
        compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

    logwri = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge final result written to file.'
    print(logwri)
# Out:
# Merge results
# Mask creation Start 2025-03-14 17:34:32
# Merge Start 2025-03-14 17:34:33
# 2025-03-14 17:34:36 - Merge results complete.
# 2025-03-14 17:46:18 - Merge final result written to file.

# %% [markdown]
# #### JNCC

# %%
# Rasterizing JNCC PAs
poly = f'{preppedDat_path}JNCC_Ramsar_SPA.gpkg'
rast = f'{preppedDat_path}UKCEH_LC_2023_10m.tif'
logpath = f'{interimFiles_path}polyrast/PAs_JNCC_polyrast_001.txt'
polyrast(poly_path = poly, raster_path = rast, logpath = logpath)
# Out:
# Process Start 2025-02-03 21:28:41
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/JNCC_Ramsar_SPA.tiff.
#  Processing....
#
# Read ref raster Start 2025-02-03 21:28:41
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/UKCEH_LULC_10m.tif
# Read poly Start 2025-02-03 21:28:42
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/JNCC_Ramsar_SPA.gpkg
# Rasterize poly Start 2025-02-03 21:29:35
# Writing rasterized poly to file Start 2025-02-03 21:34:50
# Process End 2025-02-03 21:41:24
# Code block run in 0:12:42.255112

# %% [markdown]
# ####  Wind Turbines Spatial Framework Scotland

# %%
tur_path = f'{rawDat_path}Protected Areas/Wind_Turbine_Spatial_Framework_-_Scotland/pub_wtsf.shp'
tur = gpd.read_file(tur_path)

# %%
tur_sel = tur.loc[tur['group_cat']=='Group 1']
tur_sel
# Out:
#            local_auth group_cat  \
# 4     Argyll and Bute   Group 1
# 5     Argyll and Bute   Group 1
# 15   Scottish Borders   Group 1
# 22   Scottish Borders   Group 1
# 27   Scottish Borders   Group 1
# ..                ...       ...
# 686  Scottish Borders   Group 1
# 687  Scottish Borders   Group 1
# 688  Scottish Borders   Group 1
# 689  Scottish Borders   Group 1
# 690  Scottish Borders   Group 1
#
#                                                details  la_s_code  \
# 4    Group 1 - Area where wind farms will not be ac...  S12000035
# 5    Group 1 - Area where wind farms will not be ac...  S12000035
# 15   Group 1 - Area where wind farms will not be ac...  S12000026
# 22   Group 1 - Area where wind farms will not be ac...  S12000026
# 27   Group 1 - Area where wind farms will not be ac...  S12000026
# ..                                                 ...        ...
# 686  Group 1 - Area where wind farms will not be ac...  S12000026
# 687  Group 1 - Area where wind farms will not be ac...  S12000026
# 688  Group 1 - Area where wind farms will not be ac...  S12000026
# 689  Group 1 - Area where wind farms will not be ac...  S12000026
# 690  Group 1 - Area where wind farms will not be ac...  S12000026
#
#                                    sh_src  sh_src_id  sh_date_up  \
# 4    48001def-3a1e-4156-87a0-338b06831da6          4  2025-01-20
# 5    48001def-3a1e-4156-87a0-338b06831da6          1  2025-01-20
# 15   54f3db36-3b87-4604-bbe3-43bd7c202d51       2654  2020-06-30
# 22   54f3db36-3b87-4604-bbe3-43bd7c202d51       2286  2020-06-30
# 27   54f3db36-3b87-4604-bbe3-43bd7c202d51       6127  2020-06-30
# ..                                    ...        ...         ...
# 686  54f3db36-3b87-4604-bbe3-43bd7c202d51       7490  2020-06-30
# 687  54f3db36-3b87-4604-bbe3-43bd7c202d51       1913  2020-06-30
# 688  54f3db36-3b87-4604-bbe3-43bd7c202d51       7501  2020-06-30
# 689  54f3db36-3b87-4604-bbe3-43bd7c202d51       1719  2020-06-30
# 690  54f3db36-3b87-4604-bbe3-43bd7c202d51       2223  2020-06-30
#
#                                               geometry
# 4    POLYGON ((227875.160 718070.090, 227913.500 71...
# 5    MULTIPOLYGON (((150127.780 682844.070, 150130....
# 15   POLYGON ((323308.620 640466.140, 323310.520 64...
# 22   POLYGON ((321623.060 639607.730, 321601.010 63...
# 27   POLYGON ((356091.460 634898.600, 356087.170 63...
# ..                                                 ...
# 686  POLYGON ((360425.450 632415.000, 360425.400 63...
# 687  POLYGON ((323537.850 640416.160, 323540.980 64...
# 688  POLYGON ((356846.320 634763.120, 356826.740 63...
# 689  POLYGON ((321167.380 639723.680, 321166.720 63...
# 690  POLYGON ((312438.230 632360.380, 312438.650 63...
#
# [450 rows x 8 columns]

# %%
tur_sel.to_file(f'{preppedDat_path}Wind_Turbine_Spatial_Framework_(Scot)_Cat1.gpkg')

# %% [markdown]
# ##### Run polyrast

# %%
# Rasterize
poly_path = f'{preppedDat_path}Wind_Turbine_Spatial_Framework_(Scot)_Cat1.gpkg'
logpath = f'{interimFiles_path}polyrast/WTSF_Scot_polyrast_001.txt'
raster_path = f'{preppedDat_path}UKCEH_LC_2023_10m.tif'
polyrast(poly_path, raster_path, logpath)
# Out:
# Polyrast Start 2025-03-01 14:25:59
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/Wind_Turbine_Spatial_Framework_(Scot)_Cat1.tif.
#  Processing....
# Read ref raster Start 2025-03-01 14:25:59
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/UKCEH_LC_2023_10m.tif
# Read poly Start 2025-03-01 14:25:59
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/Wind_Turbine_Spatial_Framework_(Scot)_Cat1.gpkg
# Rasterize poly Start 2025-03-01 14:25:59
# Writing rasterized poly to file Start 2025-03-01 14:26:15
# Polyrast End 2025-03-01 14:27:13
# Polyras Code block run in 0:01:14.708925
# 'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/Wind_Turbine_Spatial_Framework_(Scot)_Cat1.tif'

# %% [markdown]
# ### Peatland

# %% [markdown]
# #### Scotland

# %%
pl_path = f'{rawDat_path}Peatland/Carbon_And_Peatland_2016_map_1973336994081578535.gpkg'
pl_gdf = gpd.read_file(pl_path)

# %%
pl_gdf
# Out:
#         OBJECTID_1  FID_GIS_EX                 PRIMARY_LA  SECONDARY  \
# 0                1       21324        Smooth grass/rushes        150
# 1                2       21327  Coniferous (semi-natural)         73
# 2                3       21329     Blanket bog/peat. veg.        182
# 3                4       21329     Blanket bog/peat. veg.        182
# 4                5       21330     Blanket bog/peat. veg.        182
# ...            ...         ...                        ...        ...
# 439695      439696       22647           Improved pasture        150
# 439696      439697       22649          Undiff. broadleaf         76
# 439697      439698       22649          Undiff. broadleaf         76
# 439698      439699       22650           Improved pasture         90
# 439699      439700       22652     Smooth grass/low scrub        171
#
#                        SECONDARY_  LCS_CODE  NEW_CODE  \
# 0             Smooth grass/rushes     150.0       5.0
# 1       Coniferous (semi-natural)      73.0       0.0
# 2          Blanket bog/peat. veg.     182.0      10.0
# 3          Blanket bog/peat. veg.     182.0      10.0
# 4          Blanket bog/peat. veg.     182.0      10.0
# ...                           ...       ...       ...
# 439695        Smooth grass/rushes     150.0       5.0
# 439696          Undiff. broadleaf      76.0       0.0
# 439697          Undiff. broadleaf      76.0       0.0
# 439698           Improved pasture      90.0       0.0
# 439699            Undiff. bracken     171.0       2.0
#
#                        LCS88_LABE  LCS_CODE_P  NEW_CODE_P  ... MSSG_COMB  \
# 0             Smooth grass/rushes       150.0         5.0  ...    3.2.1.
# 1       Coniferous (semi-natural)        73.0         0.0  ...    4.1.6.
# 2          Blanket bog/peat. veg.       182.0        10.0  ...    1.4.2.
# 3          Blanket bog/peat. veg.       182.0        10.0  ...    3.2.1.
# 4          Blanket bog/peat. veg.       182.0        10.0  ...    3.3.2.
# ...                           ...         ...         ...  ...       ...
# 439695        Smooth grass/rushes        90.0         0.0  ...    4.1.4.
# 439696          Undiff. broadleaf        76.0         0.0  ...    3.3.2.
# 439697          Undiff. broadleaf        76.0         0.0  ...    4.1.4.
# 439698           Improved pasture        90.0         0.0  ...    3.3.2.
# 439699            Undiff. bracken       156.0         3.0  ...    3.3.2.
#
#                      MSSG_NAME CARBON_25  CONC_CARBO  SHAPE_LENG  CONC_CODE1  \
# 0                 Brown earths         0           1  751.357993         1C1
# 1                  Peaty gleys         0           5  214.071020          50
# 2       Mineral alluvial soils         0           1  594.076360          1E
# 3                 Brown earths         0           1   72.764092          1E
# 4           Humus-iron podzols         0           1  980.577685          1E
# ...                        ...       ...         ...         ...         ...
# 439695     Noncalcareous gleys         1           1  600.278362         1A2
# 439696      Humus-iron podzols         1           1  522.587658          10
# 439697     Noncalcareous gleys         1           1  320.013217          10
# 439698      Humus-iron podzols         1           1  539.674669          10
# 439699      Humus-iron podzols         1           1  216.758710         1A1
#
#        IMPORTANCE PRIMARY1 SE_ANNO_CAD_DATA  \
# 0               0      150            b'00'
# 1               5       73              b''
# 2               0      182            b'00'
# 3               0      182              b''
# 4               0      182            b'00'
# ...           ...      ...              ...
# 439695          0       90              b''
# 439696          0       76            b'00'
# 439697          0       76              b''
# 439698          0       90            b'00'
# 439699          0      156              b''
#
#                                                  geometry
# 0       MULTIPOLYGON (((247179.484 873798.063, 247166....
# 1       MULTIPOLYGON (((191475.011 873158.699, 191470....
# 2       MULTIPOLYGON (((247718.016 873393.438, 247726....
# 3       MULTIPOLYGON (((247651.008 873539.259, 247635....
# 4       MULTIPOLYGON (((175016.806 872804.600, 175010....
# ...                                                   ...
# 439695  MULTIPOLYGON (((274589.250 875075.625, 274626....
# 439696  MULTIPOLYGON (((274929.844 875133.250, 274895....
# 439697  MULTIPOLYGON (((275007.058 875107.000, 275000....
# 439698  MULTIPOLYGON (((276751.531 875171.625, 276647....
# 439699  MULTIPOLYGON (((275053.781 875385.812, 275061....
#
# [439700 rows x 50 columns]

# %%
pl_gdf['PRIMARY_LA'].unique()
# Out:
# array(['Smooth grass/rushes', 'Coniferous (semi-natural)',
#        'Blanket bog/peat. veg.', 'Undiff. heather moor',
#        'Wet heather moor', 'Cliffs', 'Other peat', 'Improved pasture',
#        'Undiff. bracken', 'Water', 'Recent ploughing', 'Quarries',
#        'Open canopy (young plantation)', 'Montane veg.',
#        'Undiff. Nardus/Molinia', 'Undiff. low scrub', 'Undiff. broadleaf',
#        'Undiff. smooth grass.', 'Dry heather moor',
#        'Coniferous (plantation)', 'Arable', 'Links area - grass',
#        'Recent felling', 'Smooth grass/low scrub', 'Industrial peat',
#        'Wetlands', 'Undiff. mixed woodland', 'Maritime grassland',
#        'Undiff. salt marsh', 'Built-up', 'Dubh lochans', 'Dune lands',
#        'Snow cover', 'Cemetries', 'Caravan sites', 'No-photography',
#        'Road', 'Golf course', 'Bings (area)', 'Airfield', 'Estuary', ' ',
#        'Factory', 'Forestry ripping', 'Cloud cover', 'Rail',
#        'Links area - heath', 'Ski tows', 'Rhododendron', 'Imp. pasture'],
#       dtype=object)

# %%
pl_gdf['SECONDARY_'].unique()
# Out:
# array(['Smooth grass/rushes', 'Coniferous (semi-natural)',
#        'Blanket bog/peat. veg.', 'Undiff. heather moor',
#        'Wet heather moor', 'Cliffs', 'Other peat', 'Undiff. bracken',
#        'Improved pasture', 'Water', 'Montane veg.', 'Recent ploughing',
#        'Quarries', 'Open canopy (young plantation)',
#        'Undiff. smooth grass.', 'Undiff. low scrub', 'Undiff. broadleaf',
#        'Dry heather moor', 'Coniferous (plantation)',
#        'Undiff. Nardus/Molinia', 'Arable', 'Links area - grass',
#        'Recent felling', 'Smooth grass/low scrub', 'Industrial peat',
#        'Wetlands', 'Undiff. mixed woodland', 'Maritime grassland',
#        'Undiff. salt marsh', 'Built-up', 'Dubh lochans', 'Dune lands',
#        'Snow cover', 'Cemetries', 'Caravan sites', 'No-photography',
#        'Undiff. broadleaf (point)', 'Road', 'Rhododendron', 'Golf course',
#        'Bings (area)', 'Airfield', 'Estuary', ' ', 'Factory',
#        'Forestry ripping', 'Cloud cover', 'Rail', 'Links area - heath',
#        'Ski tows', 'Undiff. mixed woodland (line)', ' Undiff. broadleaf',
#        'U.MIX WOOD (P)', 'Coniferous (plantation - point)',
#        'Undiff. broadleaf (line)', 'CON.(PLT)(L)', 'Water (point)',
#        'CON.(S/NAT)(P)', 'Isolated building'], dtype=object)

# %%
pl_gdf.loc[pl_gdf['PRIMARY_LA'].isin([
        'Blanket bog/peat. veg.', 'Other peat',
       'Undiff. Nardus/Molinia', 'Industrial peat'
        ])]['SECONDARY_'].unique()
# Out:
# array(['Blanket bog/peat. veg.', 'Other peat', 'Undiff. heather moor',
#        'Montane veg.', 'Wet heather moor', 'Industrial peat',
#        'Undiff. Nardus/Molinia', 'Improved pasture',
#        'Undiff. smooth grass.', 'Smooth grass/rushes',
#        'Maritime grassland', 'Undiff. low scrub', 'Undiff. bracken',
#        'Dry heather moor', 'Wetlands', 'Smooth grass/low scrub',
#        'Undiff. broadleaf', 'Dubh lochans', 'Coniferous (plantation)',
#        'Recent ploughing', 'Undiff. mixed woodland', 'CON.(S/NAT)(P)',
#        'Ski tows', 'Cliffs', 'Water (point)'], dtype=object)

# %%
pl_gdf.loc[pl_gdf['SECONDARY_']=='Other peat']['PRIMARY_LA'].unique()
# Out:
# array(['Other peat', 'Blanket bog/peat. veg.', 'Improved pasture',
#        'Undiff. heather moor', 'Wet heather moor', 'Smooth grass/rushes',
#        'Undiff. bracken', 'Maritime grassland'], dtype=object)

# %%
# Selecting based on primary and secondary category
pl_sel = pl_gdf.loc[(pl_gdf['PRIMARY_LA'].isin([
        'Blanket bog/peat. veg.', 'Other peat',
       'Undiff. Nardus/Molinia', 'Industrial peat'
        ]))|(pl_gdf['SECONDARY_'].isin([
       'Blanket bog/peat. veg.',
       'Other peat', 
       'Undiff. Nardus/Molinia', 'Industrial peat'
        ]))][['geometry', 'PRIMARY_LA', 'SECONDARY_', 'LCS88_LABE', 'MSSG_NAME', 'CARBON_25', 'CONC_CARBO', 'IMPORTANCE']] # selecting only minimal amount of columns as some of the data is causing export issues
pl_sel
# Out:
#                                                  geometry  \
# 2       MULTIPOLYGON (((247718.016 873393.438, 247726....
# 3       MULTIPOLYGON (((247651.008 873539.259, 247635....
# 4       MULTIPOLYGON (((175016.806 872804.600, 175010....
# 5       MULTIPOLYGON (((177131.289 873202.361, 177124....
# 6       MULTIPOLYGON (((176790.469 873151.795, 176782....
# ...                                                   ...
# 439624  MULTIPOLYGON (((264989.313 877584.750, 265006....
# 439625  MULTIPOLYGON (((264576.969 876849.000, 264564....
# 439640  MULTIPOLYGON (((266445.469 875309.000, 266350....
# 439655  MULTIPOLYGON (((265381.875 876773.750, 265368....
# 439656  MULTIPOLYGON (((265382.474 876755.751, 265362....
#
#                     PRIMARY_LA              SECONDARY_  \
# 2       Blanket bog/peat. veg.  Blanket bog/peat. veg.
# 3       Blanket bog/peat. veg.  Blanket bog/peat. veg.
# 4       Blanket bog/peat. veg.  Blanket bog/peat. veg.
# 5       Blanket bog/peat. veg.  Blanket bog/peat. veg.
# 6       Blanket bog/peat. veg.  Blanket bog/peat. veg.
# ...                        ...                     ...
# 439624    Undiff. heather moor  Blanket bog/peat. veg.
# 439625    Undiff. heather moor  Blanket bog/peat. veg.
# 439640              Other peat              Other peat
# 439655  Blanket bog/peat. veg.  Blanket bog/peat. veg.
# 439656  Blanket bog/peat. veg.  Blanket bog/peat. veg.
#
#                     LCS88_LABE                MSSG_NAME  CARBON_25  \
# 2       Blanket bog/peat. veg.   Mineral alluvial soils          0
# 3       Blanket bog/peat. veg.             Brown earths          0
# 4       Blanket bog/peat. veg.       Humus-iron podzols          0
# 5       Blanket bog/peat. veg.              Peaty gleys          0
# 6       Blanket bog/peat. veg.              Peaty gleys          0
# ...                        ...                      ...        ...
# 439624  Blanket bog/peat. veg.  Dystrophic blanket peat          0
# 439625  Blanket bog/peat. veg.  Dystrophic blanket peat          0
# 439640              Other peat     Peaty gleyed podzols          0
# 439655  Blanket bog/peat. veg.     Peaty gleyed podzols          0
# 439656  Blanket bog/peat. veg.  Dystrophic blanket peat          0
#
#         CONC_CARBO  IMPORTANCE
# 2                1           0
# 3                1           0
# 4                1           0
# 5                5           1
# 6                5           1
# ...            ...         ...
# 439624           6           1
# 439625           6           1
# 439640           5           1
# 439655           5           1
# 439656           6           1
#
# [86427 rows x 8 columns]

# %%
pl_sel.to_file(f'{preppedDat_path}Scotland_2016_peat_Primary_Secondary.gpkg')

# %%
# Selecting only based on primary category
pl_sel_primaryOnly = pl_gdf.loc[(pl_gdf['PRIMARY_LA'].isin([
        'Blanket bog/peat. veg.', 'Other peat',
       'Undiff. Nardus/Molinia', 'Industrial peat'
        ]))][['geometry', 'PRIMARY_LA', 'SECONDARY_', 'LCS88_LABE', 'MSSG_NAME', 'CARBON_25', 'CONC_CARBO', 'IMPORTANCE']]
pl_sel_primaryOnly
# Out:
#                                                  geometry  \
# 2       MULTIPOLYGON (((247718.016 873393.438, 247726....
# 3       MULTIPOLYGON (((247651.008 873539.259, 247635....
# 4       MULTIPOLYGON (((175016.806 872804.600, 175010....
# 5       MULTIPOLYGON (((177131.289 873202.361, 177124....
# 6       MULTIPOLYGON (((176790.469 873151.795, 176782....
# ...                                                   ...
# 439619  MULTIPOLYGON (((262949.363 876285.548, 262818....
# 439620  MULTIPOLYGON (((262221.510 876734.490, 262234....
# 439640  MULTIPOLYGON (((266445.469 875309.000, 266350....
# 439655  MULTIPOLYGON (((265381.875 876773.750, 265368....
# 439656  MULTIPOLYGON (((265382.474 876755.751, 265362....
#
#                     PRIMARY_LA              SECONDARY_  \
# 2       Blanket bog/peat. veg.  Blanket bog/peat. veg.
# 3       Blanket bog/peat. veg.  Blanket bog/peat. veg.
# 4       Blanket bog/peat. veg.  Blanket bog/peat. veg.
# 5       Blanket bog/peat. veg.  Blanket bog/peat. veg.
# 6       Blanket bog/peat. veg.  Blanket bog/peat. veg.
# ...                        ...                     ...
# 439619              Other peat              Other peat
# 439620              Other peat              Other peat
# 439640              Other peat              Other peat
# 439655  Blanket bog/peat. veg.  Blanket bog/peat. veg.
# 439656  Blanket bog/peat. veg.  Blanket bog/peat. veg.
#
#                     LCS88_LABE                MSSG_NAME  CARBON_25  \
# 2       Blanket bog/peat. veg.   Mineral alluvial soils          0
# 3       Blanket bog/peat. veg.             Brown earths          0
# 4       Blanket bog/peat. veg.       Humus-iron podzols          0
# 5       Blanket bog/peat. veg.              Peaty gleys          0
# 6       Blanket bog/peat. veg.              Peaty gleys          0
# ...                        ...                      ...        ...
# 439619              Other peat              Peaty gleys          0
# 439620              Other peat  Dystrophic blanket peat          0
# 439640              Other peat     Peaty gleyed podzols          0
# 439655  Blanket bog/peat. veg.     Peaty gleyed podzols          0
# 439656  Blanket bog/peat. veg.  Dystrophic blanket peat          0
#
#         CONC_CARBO  IMPORTANCE
# 2                1           0
# 3                1           0
# 4                1           0
# 5                5           1
# 6                5           1
# ...            ...         ...
# 439619           5           1
# 439620           6           1
# 439640           5           1
# 439655           5           1
# 439656           6           1
#
# [52802 rows x 8 columns]

# %%
pl_sel_primaryOnly.to_file(f'{preppedDat_path}Scotland_2016_peat_Primary.gpkg')

# %%
# Selecting secondary only
# Selecting based on primary and secondary category
pl_sel_sec = pl_gdf.loc[(pl_gdf['SECONDARY_'].isin([
       'Blanket bog/peat. veg.','Other peat', 
       'Undiff. Nardus/Molinia', 'Industrial peat'
        ]))][['geometry', 'PRIMARY_LA', 'SECONDARY_', 'LCS88_LABE', 'MSSG_NAME', 'CARBON_25', 'CONC_CARBO', 'IMPORTANCE']] # selecting only minimal amount of columns as some of the data is causing export issues
pl_sel_sec.to_file(f'{preppedDat_path}Scotland_2016_peat_Secondary.gpkg')

# %% [markdown]
# #### England

# %%
en_pl_path = f'{rawDat_path}Peatland/Peaty_Soils_Location_-4629138299390543035.gpkg'
en_pl_gdf = gpd.read_file(en_pl_path)

# %%
en_pl_gdf['PCLASSDESC'].unique()
# Out:
# array(['Deep Peaty Soils', 'Shallow Peaty Soils',
#        'Soils with Peaty Pockets'], dtype=object)

# %%
en_peat = en_pl_gdf.loc[en_pl_gdf['PCLASSDESC'].isin(['Deep Peaty Soils', 'Shallow Peaty Soils'])]
en_peat.to_file(f'{preppedDat_path}England_Peaty_Soils_Location_Deep_Shallow.gpkg')

# %%
en_pockets = en_pl_gdf.loc[en_pl_gdf['PCLASSDESC'] == 'Soils with Peaty Pockets']
en_pockets.to_file(f'{preppedDat_path}England_Peaty_Soils_Location_Pockets.gpkg')

# %% [markdown]
# #### Wales

# %%
# Shapefile contains only 1 geom, just need to rasterize
poly_path = f'{rawDat_path}Peatland/peatlands_of_wales_scg8.gpkg'
logpath = f'{interimFiles_path}polyrast/Peat_Wales_polyrast_001.txt'
raster_path = f'{preppedDat_path}UKCEH_LC_2023_10m.tif'

polyrast(poly_path, raster_path, logpath)
# Out:
# Polyrast Start 2025-03-01 18:57:26
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/peatlands_of_wales_scg8.tif.
#  Processing....
# Read ref raster Start 2025-03-01 18:57:26
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/UKCEH_LC_2023_10m.tif
# Read poly Start 2025-03-01 18:57:26
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/Peatland/peatlands_of_wales_scg8.gpkg
# Rasterize poly Start 2025-03-01 18:57:28
# Writing rasterized poly to file Start 2025-03-01 18:57:36
# Polyrast End 2025-03-01 18:58:17
# Polyras Code block run in 0:00:51.075921
# 'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/peatlands_of_wales_scg8.tif'

# %% [markdown]
# #### Rasterize Eng and Scot layers

# %%
# Rasterize
scot1 = f'{preppedDat_path}Scotland_2016_peat_Primary.gpkg'
scot2 = f'{preppedDat_path}Scotland_2016_peat_Secondary.gpkg'
eng1 = f'{preppedDat_path}England_Peaty_Soils_Location_Deep_Shallow.gpkg'
eng2 = f'{preppedDat_path}England_Peaty_Soils_Location_Pockets.gpkg'
poly_paths = [scot1, scot2, eng1, eng2]
logpath = f'{interimFiles_path}polyrast/Peat_polyrast_001.txt'
raster_path = f'{preppedDat_path}UKCEH_LC_2023_10m.tif'
for i in poly_paths:
    polyrast(i, raster_path, logpath)
# Out:
# Polyrast Start 2025-03-01 18:59:27
# File already exists: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/Scotland_2016_peat_Primary.tif.
#  Skipping....
# ('vector' var could not be deleted, likely doesn't exist)
# ('geom' var could not be deleted, likely doesn't exist)
# ('rasterized' var could not be deleted, likely doesn't exist)
# ('src' var could not be deleted, likely doesn't exist)
# Polyrast End 2025-03-01 18:59:27
# Polyras Code block run in 0:00:00.008745
#
# Polyrast Start 2025-03-01 18:59:27
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/Scotland_2016_peat_Secondary.tif.
#  Processing....
# Read ref raster Start 2025-03-01 18:59:27
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/UKCEH_LC_2023_10m.tif
# Read poly Start 2025-03-01 18:59:27
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/Scotland_2016_peat_Secondary.gpkg
# Rasterize poly Start 2025-03-01 18:59:55
# Writing rasterized poly to file Start 2025-03-01 19:00:31
# Polyrast End 2025-03-01 19:01:29
# Polyras Code block run in 0:02:01.938683
#
# Polyrast Start 2025-03-01 19:01:29
# File already exists: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/England_Peaty_Soils_Location_Deep_Shallow.tif.
#  Skipping....
# ('vector' var could not be deleted, likely doesn't exist)
# ('geom' var could not be deleted, likely doesn't exist)
# ('rasterized' var could not be deleted, likely doesn't exist)
# ('src' var could not be deleted, likely doesn't exist)
# Polyrast End 2025-03-01 19:01:29
# Polyras Code block run in 0:00:00.043543
#
# Polyrast Start 2025-03-01 19:01:29
# File already exists: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/England_Peaty_Soils_Location_Pockets.tif.
#  Skipping....
# ('vector' var could not be deleted, likely doesn't exist)
# ('geom' var could not be deleted, likely doesn't exist)
# ('rasterized' var could not be deleted, likely doesn't exist)
# ('src' var could not be deleted, likely doesn't exist)
# Polyrast End 2025-03-01 19:01:29
# Polyras Code block run in 0:00:00.028424

# %% [markdown]
# #### Merge similar categories across countries

# %%
write_path = f'{preppedDat_path}Peatland/Peatland_Lvl1_merged.tif'
path1 = f'{preppedDat_path}Peatland/England_Peaty_Soils_Location_Deep_Shallow.tif'
path2 = f'{preppedDat_path}Peatland/Scotland_2016_peat_Primary.tif'
path3 = f'{preppedDat_path}Peatland/peatlands_of_wales_scg8.tif'

with rio.open(path1) as src_1:
    dask_ar_1 = da.from_array(src_1.read(1), chunks= 100)

with rio.open(path2) as src_2:
    dask_ar_2 = da.from_array(src_2.read(1), chunks= 100)

    # Merging 1-2
    logmsk = f'Merge 1-2\n Mask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logmsk)
    mask = dask_ar_1 > 0 # Make a boolean array out of non-null raster pixels
    logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logdifst)
    processed_data = da.where(mask, 1, dask_ar_2) #Pixels in mask set to 1        
    logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge 1-2 complete.'
    print(logdif)
    # Merging result - 3
    with rio.open(path3) as src_3:
        dask_ar_3 = da.from_array(src_3.read(1), chunks= 100)
    logmsk = f'Merge result-3\n Mask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logmsk)
    mask = processed_data > 0 # Make a boolean array out of non-null raster pixels
    logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logdifst)
    processed_data = da.where(mask, 1, dask_ar_3) #Pixels in mask set to 1       
    logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge result-3 complete.'
    print(logdif)
    # Write result to file
    with rio.open(
        write_path, 'w',
        driver='GTiff',
        height=processed_data.shape[0],
        width=processed_data.shape[1],
        count=1,
        dtype=processed_data.dtype,
        crs=src_1.crs,
        transform=src_1.transform,
        compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

    logwri = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge final result written to file.'
    print(logwri)
# Out:
# Merge 1-2
#  Mask creation Start 2025-03-07 15:16:36
# Merge Start 2025-03-07 15:16:36
# 2025-03-07 15:16:36 - Merge 1-2 complete.
# Merge result-3
#  Mask creation Start 2025-03-07 15:17:05
# Merge Start 2025-03-07 15:17:05
# 2025-03-07 15:17:05 - Merge result-3 complete.
# 2025-03-07 15:31:54 - Merge final result written to file.

# %%
write_path = f'{preppedDat_path}Peatland/Peatland_Lvl2_merged.tif'
path1 = f'{preppedDat_path}Peatland/Scotland_2016_peat_Secondary.tif'
path2 = f'{preppedDat_path}Peatland/England_Peaty_Soils_Location_Pockets.tif'

with rio.open(path1) as src_1:
    dask_ar_1 = da.from_array(src_1.read(1), chunks= 100)

with rio.open(path2) as src_2:
    dask_ar_2 = da.from_array(src_2.read(1), chunks= 100)

    # Merging 1-2
    logmsk = f'Merge 1-2\n Mask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logmsk)
    mask = dask_ar_1 > 0 # Make a boolean array out of non-null raster pixels
    logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logdifst)
    processed_data = da.where(mask, 1, dask_ar_2) #Pixels in mask set to 1        
    logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge 1-2 complete.'
    print(logdif)
    
    # Write result to file
    with rio.open(
        write_path, 'w',
        driver='GTiff',
        height=processed_data.shape[0],
        width=processed_data.shape[1],
        count=1,
        dtype=processed_data.dtype,
        crs=src_1.crs,
        transform=src_1.transform,
        compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

    logwri = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge final result written to file.'
    print(logwri)
# Out:
# Merge 1-2
#  Mask creation Start 2025-03-07 15:33:25
# Merge Start 2025-03-07 15:33:26
# 2025-03-07 15:33:29 - Merge 1-2 complete.
# 2025-03-07 15:45:52 - Merge final result written to file.

# %% [markdown]
# #### Merge categories (for peatstats)

# %%
write_path = f'{preppedDat_path}Peatland/Peatland_all_Lvl.tif'
path1 = f'{preppedDat_path}Peatland/Peatland_Lvl1_merged.tif'
path2 = f'{preppedDat_path}Peatland/Peatland_Lvl2_merged.tif'

with rio.open(path1) as src_1:
    dask_ar_1 = da.from_array(src_1.read(1), chunks= 100)

with rio.open(path2) as src_2:
    dask_ar_2 = da.from_array(src_2.read(1), chunks= 100)

    # Merging 2-1
    logmsk = f'Merge 2-1\nMask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logmsk)
    mask = dask_ar_1 > 0 # Make a boolean array out of non-null raster pixels
    logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logdifst)
    processed_data = da.where(mask, 1, dask_ar_2*2)     
    logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge 1-2 complete.'
    print(logdif)
    
    # Write result to file
    with rio.open(
        write_path, 'w',
        driver='GTiff',
        height=processed_data.shape[0],
        width=processed_data.shape[1],
        count=1,
        dtype=processed_data.dtype,
        crs=src_1.crs,
        transform=src_1.transform,
        compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

    logwri = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge final result written to file.'
    print(logwri)
# Out:
# Merge 2-1
# Mask creation Start 2025-03-11 11:20:22
# Merge Start 2025-03-11 11:20:22
# 2025-03-11 11:20:22 - Merge 1-2 complete.
# 2025-03-11 11:32:40 - Merge final result written to file.

# %% [markdown]
# ### Agriculture

# %% [markdown]
# #### Modified polyrast to process selected categories only

# %%
# EDITED VERSION TO TAKE EXTERNALLY FILTERED GDF RATHER THAN POLY PATH
# Created 31/01
# Last edit 3/02

def cat_polyrast(poly_path, poly_select, cat_nr, raster_path, logpath):
    start = time.perf_counter()
    logstart = f'\nPolyrast Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logstart)
    with open(logpath, 'a') as logfile:
        logfile.writelines([logstart,'\n'])
    # Getting file name for output naming
    filename = os.path.basename(poly_path)
    filename_noExt = os.path.splitext(filename)[0]
    ext = os.path.splitext(filename)[1]
    polyrast_write_path = f'{interimFiles_path}polyrast/{filename_noExt}_{cat_nr}.tif'
    # Check if file exists
    if not os.path.exists(polyrast_write_path):
        logexist = f'File does not exist: {polyrast_write_path}. \n Processing....'
        print (logexist)
        # Read the reference raster
        logref = f'Read ref raster Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}\n from: {raster_path}'
        print(logref)
        with rio.open(raster_path) as src:
            # Read poly layer
            logrd = f'Read poly Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}\n from: {poly_path}'
            print(logrd)
            vector = poly_select
        
            # Rasterize poly
            #https://pygis.io/docs/e_raster_rasterize.html
            geom = [shapes for shapes in vector.geometry]
            logras = f'Rasterize poly Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
            print(logras)
            # Rasterize vector using the shape and coordinate system of the raster
            rasterized = features.rasterize(geom, out_shape = src.shape, fill = 0, out = None, transform = src.transform, all_touched = False, default_value = 1, dtype = None) # All touched = False --> only pixels fully inside the geom
        
            # Write to file
            logwri = f'Writing rasterized poly to file Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
            print(logwri)
            with rio.open(
            polyrast_write_path, 'w',
            driver='GTiff',
            height=src.shape[0],
            width=src.shape[1],
            count=1,
            dtype=rasterized.dtype,
            crs=src.crs,
            transform=src.transform,
            compress='DEFLATE'
            ) as dst:
                dst.write(rasterized, 1)
        with open(logpath, 'a') as logfile:
            logfile.writelines([logexist,'\n',logref,'\n',logrd,'\n',logras,'\n',logwri,'\n'])
    else:
        logexist = f'File already exists: {polyrast_write_path}. \n Skipping....'
        print (logexist)
        with open(logpath, 'a') as logfile:
            logfile.writelines([logexist,'\n'])

    # Clearing variables for memory
    try:
        del vector
    except:
        print("('vector' var could not be deleted, likely doesn't exist)")
    try:
        del geom
    except:
        print("('geom' var could not be deleted, likely doesn't exist)")
    try:
        del rasterized
    except:
        print("('rasterized' var could not be deleted, likely doesn't exist)")
    try:
        del src
    except:
        print("('src' var could not be deleted, likely doesn't exist)")
    
    logend = f'Polyrast End {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logend)
    end = time.perf_counter()
    elapsed_time = end - start
    # Convert the elapsed time to a timedelta object 
    elapsed_time_str = str(timedelta(seconds=elapsed_time))
    logrun = f'Polyras Code block run in {elapsed_time_str}'
    print(logrun)
    with open(logpath, 'a') as logfile:
        logfile.writelines([logend,'\n', logrun])
    return polyrast_write_path

# %% [markdown]
# #### Scotland

# %%
poly_path = f'{rawDat_path}Agricultural Grades/Scotland/LCA_50K_250K_union.gpkg'
poly_df = gpd.read_file(poly_path)

# %%
poly_df
# Out:
#            AREA  PERIMETER  LCCODE Prime Scale  Hectares    SqMid     AREA_2  \
# 0       9884.79    422.589  9500.0    No  250K  0.988479    Other        NaN
# 1      19595.20    663.765  9500.0    No  250K  1.959518    Other        NaN
# 2       4408.03    332.904  9500.0    No  250K  0.440803    Other        NaN
# 3      27771.40   1468.150     6.3    No  250K  2.777137  Uplands        NaN
# 4       3092.27    277.096  9500.0    No  250K  0.309227    Other        NaN
# ...         ...        ...     ...   ...   ...       ...      ...        ...
# 53407       NaN        NaN     NaN  None  None       NaN     None  725.64400
# 53408       NaN        NaN     NaN  None  None       NaN     None   85.53840
# 53409       NaN        NaN     NaN  None  None       NaN     None   67.48350
# 53410       NaN        NaN     NaN  None  None       NaN     None    3.30451
# 53411       NaN        NaN     NaN  None  None       NaN     None    7.22233
#
#        PERIMETER_2  LCCODE_2 Scale_2 Water        AreaM2  \
# 0              NaN       NaN    None  None           NaN
# 1              NaN       NaN    None  None           NaN
# 2              NaN       NaN    None  None           NaN
# 3              NaN       NaN    None  None           NaN
# 4              NaN       NaN    None  None           NaN
# ...            ...       ...     ...   ...           ...
# 53407      45549.4       3.2     50K    No  7.256436e+06
# 53408      45549.4       3.2     50K    No  8.553836e+05
# 53409      12067.0     888.0     50K    No  6.748347e+05
# 53410      31637.9       3.2     50K    No  4.461351e+06
# 53411      31637.9       3.2     50K    No  4.461351e+06
#
#                                                 geometry
# 0      MULTIPOLYGON (((461247.656 1220190.000, 461243...
# 1      MULTIPOLYGON (((460656.062 1219565.000, 460640...
# 2      MULTIPOLYGON (((460751.219 1219542.500, 460736...
# 3      MULTIPOLYGON (((460463.250 1219243.875, 460450...
# 4      MULTIPOLYGON (((460453.875 1219313.875, 460430...
# ...                                                  ...
# 53407  MULTIPOLYGON (((367030.500 758705.313, 367005....
# 53408  MULTIPOLYGON (((368141.988 756680.693, 368169....
# 53409  MULTIPOLYGON (((372276.460 756809.209, 372263....
# 53410  MULTIPOLYGON (((377272.594 769719.625, 377268....
# 53411  MULTIPOLYGON (((377550.844 769215.688, 377546....
#
# [53412 rows x 14 columns]

# %%
poly_df['LCCODE_2'].unique()
# Out:
# array([     nan, 6.20e+00, 4.20e+00, 5.20e+00, 5.30e+00, 6.30e+00,
#        9.99e+02, 4.10e+00, 8.88e+02, 3.20e+00, 6.10e+00, 7.00e+00,
#        5.10e+00, 3.10e+00, 2.00e+00, 9.50e+03, 1.00e+00])

# %%
poly_df['LCCODE'].unique()
# Out:
# array([9.50e+03, 6.30e+00, 6.20e+00, 5.20e+00, 5.30e+00, 4.20e+00,
#        9.99e+02, 7.00e+00, 8.88e+02, 5.10e+00, 6.10e+00, 4.10e+00,
#        3.20e+00, 3.10e+00, 2.00e+00,      nan])

# %% [markdown]
# ##### Agri land 1

# %%
# Agri land 1
min_cat = 0
max_cat = 2
agri1 = poly_df.loc[((poly_df['LCCODE_2']>=min_cat) & (poly_df['LCCODE_2']<max_cat))|((poly_df['LCCODE']>=min_cat) & (poly_df['LCCODE']<max_cat))]
agri1
# Out:
#        AREA  PERIMETER  LCCODE Prime Scale  Hectares SqMid      AREA_2  \
# 28530   NaN        NaN     NaN  None  None       NaN  None   171.58200
# 28579   NaN        NaN     NaN  None  None       NaN  None  1019.94000
# 28678   NaN        NaN     NaN  None  None       NaN  None    69.67790
# 32024   NaN        NaN     NaN  None  None       NaN  None   211.69700
# 32103   NaN        NaN     NaN  None  None       NaN  None    11.69850
# 32107   NaN        NaN     NaN  None  None       NaN  None   520.12900
# 32110   NaN        NaN     NaN  None  None       NaN  None     4.82070
# 32212   NaN        NaN     NaN  None  None       NaN  None     3.75999
# 32263   NaN        NaN     NaN  None  None       NaN  None   130.03200
# 32296   NaN        NaN     NaN  None  None       NaN  None     4.74589
# 32694   NaN        NaN     NaN  None  None       NaN  None    97.02540
# 33425   NaN        NaN     NaN  None  None       NaN  None     4.08788
# 37042   NaN        NaN     NaN  None  None       NaN  None    82.40990
# 37073   NaN        NaN     NaN  None  None       NaN  None    43.22720
# 37109   NaN        NaN     NaN  None  None       NaN  None    70.89340
# 37141   NaN        NaN     NaN  None  None       NaN  None   186.76800
# 52205   NaN        NaN     NaN  None  None       NaN  None    45.73220
# 52219   NaN        NaN     NaN  None  None       NaN  None   792.96500
# 52270   NaN        NaN     NaN  None  None       NaN  None   846.35500
#
#        PERIMETER_2  LCCODE_2 Scale_2 Water        AreaM2  \
# 28530     6803.890       1.0     50K    No  1.715816e+06
# 28579    36616.300       1.0     50K    No  1.019937e+07
# 28678     4624.500       1.0     50K    No  6.967789e+05
# 32024    13550.800       1.0     50K    No  2.116969e+06
# 32103     1625.580       1.0     50K    No  1.169845e+05
# 32107    16932.900       1.0     50K    No  5.201292e+06
# 32110     1040.530       1.0     50K    No  4.820703e+04
# 32212      860.705       1.0     50K    No  3.759986e+04
# 32263     5447.380       1.0     50K    No  1.300316e+06
# 32296      984.812       1.0     50K    No  4.745886e+04
# 32694     7122.720       1.0     50K    No  9.702540e+05
# 33425      790.054       1.0     50K    No  4.087883e+04
# 37042     3689.390       1.0     50K    No  8.240994e+05
# 37073     4712.880       1.0     50K    No  4.322722e+05
# 37109     4288.790       1.0     50K    No  7.089343e+05
# 37141     9661.950       1.0     50K    No  1.867685e+06
# 52205     4354.900       1.0     50K    No  4.573216e+05
# 52219    25575.300       1.0     50K    No  7.929648e+06
# 52270    23409.700       1.0     50K    No  8.463552e+06
#
#                                                 geometry
# 28530  MULTIPOLYGON (((360591.031 739919.188, 360593....
# 28579  MULTIPOLYGON (((360922.406 738448.000, 360931....
# 28678  MULTIPOLYGON (((351447.656 734670.375, 351452....
# 32024  MULTIPOLYGON (((351967.906 681356.313, 351990....
# 32103  MULTIPOLYGON (((354309.000 680094.063, 354285....
# 32107  MULTIPOLYGON (((351010.750 679127.813, 350953....
# 32110  MULTIPOLYGON (((354795.937 680208.313, 354806....
# 32212  MULTIPOLYGON (((315931.812 679103.250, 315940....
# 32263  MULTIPOLYGON (((345330.656 678673.313, 345324....
# 32296  MULTIPOLYGON (((316563.187 678478.438, 316568....
# 32694  MULTIPOLYGON (((372697.906 675349.563, 372696....
# 33425  MULTIPOLYGON (((314172.875 670360.438, 314170....
# 37042  MULTIPOLYGON (((384629.500 639526.688, 384913....
# 37073  MULTIPOLYGON (((383723.500 639097.750, 383649....
# 37109  MULTIPOLYGON (((379631.219 638913.188, 379603....
# 37141  MULTIPOLYGON (((378985.625 637585.375, 378962....
# 52205  MULTIPOLYGON (((317948.562 677417.813, 318029....
# 52219  MULTIPOLYGON (((343744.781 675603.063, 343690....
# 52270  MULTIPOLYGON (((335927.125 672508.375, 335893....

# %% [markdown]
# ##### Agri land 2

# %%
# Agri land 2
min_cat = 2
max_cat = 3
agri2 = poly_df.loc[((poly_df['LCCODE_2']>=min_cat) & (poly_df['LCCODE_2']<max_cat))|((poly_df['LCCODE']>=min_cat) & (poly_df['LCCODE']<max_cat))]
agri2
# Out:
#              AREA  PERIMETER  LCCODE Prime Scale     Hectares  SqMid  \
# 6378    6244430.0    19109.4     2.0   Yes  250K   624.442667  Prime
# 6507   16565800.0    32116.0     2.0   Yes  250K  1656.583630  Prime
# 6556    3150330.0    14262.9     2.0   Yes  250K   315.032807  Prime
# 6598    5019910.0    13143.2     2.0   Yes  250K   501.990682  Prime
# 6921    7253020.0    15964.4     2.0   Yes  250K   725.301987  Prime
# ...           ...        ...     ...   ...   ...          ...    ...
# 52729         NaN        NaN     NaN  None  None          NaN   None
# 52731         NaN        NaN     NaN  None  None          NaN   None
# 52741         NaN        NaN     NaN  None  None          NaN   None
# 52744         NaN        NaN     NaN  None  None          NaN   None
# 52762         NaN        NaN     NaN  None  None          NaN   None
#
#          AREA_2  PERIMETER_2  LCCODE_2 Scale_2 Water        AreaM2  \
# 6378        NaN          NaN       NaN    None  None           NaN
# 6507        NaN          NaN       NaN    None  None           NaN
# 6556        NaN          NaN       NaN    None  None           NaN
# 6598        NaN          NaN       NaN    None  None           NaN
# 6921        NaN          NaN       NaN    None  None           NaN
# ...         ...          ...       ...     ...   ...           ...
# 52729   20.8072      1813.52       2.0     50K    No  2.080720e+05
# 52731   25.1961      2893.49       2.0     50K    No  2.519605e+05
# 52741   20.4794      2126.50       2.0     50K    No  2.047936e+05
# 52744   77.4274      6270.35       2.0     50K    No  7.742740e+05
# 52762  291.8790     18315.10       2.0     50K    No  2.918791e+06
#
#                                                 geometry
# 6378   MULTIPOLYGON (((269789.438 868851.562, 269761....
# 6507   MULTIPOLYGON (((279004.062 864604.062, 278976....
# 6556   MULTIPOLYGON (((263460.281 864046.250, 263443....
# 6598   MULTIPOLYGON (((258785.703 862387.125, 258796....
# 6921   MULTIPOLYGON (((256071.516 857086.500, 256079....
# ...                                                  ...
# 52729  MULTIPOLYGON (((235955.531 636811.688, 235949....
# 52731  MULTIPOLYGON (((239057.187 636406.938, 239041....
# 52741  MULTIPOLYGON (((240007.562 636666.688, 240010....
# 52744  MULTIPOLYGON (((235921.906 636638.438, 235937....
# 52762  MULTIPOLYGON (((234212.766 634096.500, 234215....
#
# [571 rows x 14 columns]

# %% [markdown]
# ##### Agri land 3

# %%
# Agri land 3
min_cat = 3
max_cat = 4
agri3 = poly_df.loc[((poly_df['LCCODE_2']>=min_cat) & (poly_df['LCCODE_2']<max_cat))|((poly_df['LCCODE']>=min_cat) & (poly_df['LCCODE']<max_cat))]
agri3
# Out:
#               AREA  PERIMETER  LCCODE Prime Scale      Hectares   SqMid  \
# 1647   284064000.0   331751.0     3.2    No  250K  28406.437780  Sq Mid
# 1685    13669700.0    24257.5     3.2    No  250K   1366.967003  Sq Mid
# 4778     5419120.0    18332.2     3.2    No  250K    541.911837  Sq Mid
# 4936      618158.0     5189.3     3.2    No  250K     61.815803  Sq Mid
# 4986     5781210.0    20614.9     3.2    No  250K    578.120609  Sq Mid
# ...            ...        ...     ...   ...   ...           ...     ...
# 53406          NaN        NaN     NaN  None  None           NaN    None
# 53407          NaN        NaN     NaN  None  None           NaN    None
# 53408          NaN        NaN     NaN  None  None           NaN    None
# 53410          NaN        NaN     NaN  None  None           NaN    None
# 53411          NaN        NaN     NaN  None  None           NaN    None
#
#           AREA_2  PERIMETER_2  LCCODE_2 Scale_2 Water        AreaM2  \
# 1647         NaN          NaN       NaN    None  None           NaN
# 1685         NaN          NaN       NaN    None  None           NaN
# 4778         NaN          NaN       NaN    None  None           NaN
# 4936         NaN          NaN       NaN    None  None           NaN
# 4986         NaN          NaN       NaN    None  None           NaN
# ...          ...          ...       ...     ...   ...           ...
# 53406   85.74490      45549.4       3.2     50K    No  8.574495e+05
# 53407  725.64400      45549.4       3.2     50K    No  7.256436e+06
# 53408   85.53840      45549.4       3.2     50K    No  8.553836e+05
# 53410    3.30451      31637.9       3.2     50K    No  4.461351e+06
# 53411    7.22233      31637.9       3.2     50K    No  4.461351e+06
#
#                                                 geometry
# 1647   MULTIPOLYGON (((336765.844 962665.688, 336759....
# 1685   MULTIPOLYGON (((299881.500 965385.625, 299855....
# 4778   MULTIPOLYGON (((301017.969 913394.688, 301013....
# 4936   MULTIPOLYGON (((284450.594 909770.125, 284605....
# 4986   MULTIPOLYGON (((293314.562 908474.500, 293295....
# ...                                                  ...
# 53406  MULTIPOLYGON (((370935.401 758921.093, 370907....
# 53407  MULTIPOLYGON (((367030.500 758705.313, 367005....
# 53408  MULTIPOLYGON (((368141.988 756680.693, 368169....
# 53410  MULTIPOLYGON (((377272.594 769719.625, 377268....
# 53411  MULTIPOLYGON (((377550.844 769215.688, 377546....
#
# [5550 rows x 14 columns]

# %% [markdown]
# ##### Agri land 4

# %%
# Agri land 4
min_cat = 4
max_cat = 5
agri4 = poly_df.loc[((poly_df['LCCODE_2']>=min_cat) & (poly_df['LCCODE_2']<max_cat))|((poly_df['LCCODE']>=min_cat) & (poly_df['LCCODE']<max_cat))]
agri4
# Out:
#             AREA  PERIMETER  LCCODE Prime Scale    Hectares   SqMid    AREA_2  \
# 25     2239190.0    7523.88     4.2    No  250K  223.918635  Sq Mid       NaN
# 36      185046.0    1796.28     4.2    No  250K   18.504584  Sq Mid       NaN
# 38     6706810.0   19585.50     4.2    No  250K  670.680570  Sq Mid       NaN
# 108     347402.0    2565.67     4.2    No  250K   34.740186  Sq Mid       NaN
# 216     729333.0    4492.57     4.2    No  250K   72.933315  Sq Mid       NaN
# ...          ...        ...     ...   ...   ...         ...     ...       ...
# 53390        NaN        NaN     NaN  None  None         NaN    None  20.80770
# 53396        NaN        NaN     NaN  None  None         NaN    None  14.73670
# 53399        NaN        NaN     NaN  None  None         NaN    None  11.42290
# 53401        NaN        NaN     NaN  None  None         NaN    None   5.63755
# 53404        NaN        NaN     NaN  None  None         NaN    None   1.19104
#
#        PERIMETER_2  LCCODE_2 Scale_2 Water         AreaM2  \
# 25             NaN       NaN    None  None            NaN
# 36             NaN       NaN    None  None            NaN
# 38             NaN       NaN    None  None            NaN
# 108            NaN       NaN    None  None            NaN
# 216            NaN       NaN    None  None            NaN
# ...            ...       ...     ...   ...            ...
# 53390     1828.220       4.1     50K    No  208076.965332
# 53396     1706.180       4.1     50K    No  147367.246582
# 53399     1251.040       4.2     50K    No  114228.507324
# 53401     1662.010       4.2     50K    No   56375.544922
# 53404      486.405       4.2     50K    No   11910.421387
#
#                                                 geometry
# 25     MULTIPOLYGON (((465232.031 1214113.625, 465173...
# 36     MULTIPOLYGON (((460478.562 1211342.500, 460514...
# 38     MULTIPOLYGON (((460187.812 1210596.750, 460293...
# 108    MULTIPOLYGON (((456909.031 1201247.125, 456880...
# 216    MULTIPOLYGON (((462375.719 1191771.875, 462471...
# ...                                                  ...
# 53390  MULTIPOLYGON (((212508.062 532174.625, 212485....
# 53396  MULTIPOLYGON (((212912.625 532135.688, 212908....
# 53399  MULTIPOLYGON (((211793.703 531957.000, 211785....
# 53401  MULTIPOLYGON (((214351.969 531466.875, 214341....
# 53404  MULTIPOLYGON (((214116.516 530855.688, 214116....
#
# [12002 rows x 14 columns]

# %% [markdown]
# ##### Agri land 5+

# %%
# Agri land 5
min_cat = 5
max_cat = 8
agri5 = poly_df.loc[((poly_df['LCCODE_2']>=min_cat) & (poly_df['LCCODE_2']<max_cat))|((poly_df['LCCODE']>=min_cat) & (poly_df['LCCODE']<max_cat))]
agri5
# Out:
#              AREA  PERIMETER  LCCODE Prime Scale     Hectares    SqMid  \
# 3         27771.4    1468.15     6.3    No  250K     2.777137  Uplands
# 5         29221.4    1084.83     6.3    No  250K     2.922140  Uplands
# 7      26633500.0   51596.50     6.3    No  250K  2663.354157  Uplands
# 8       4863080.0   19050.60     6.3    No  250K   486.307555  Uplands
# 12      2548910.0   19208.70     6.2    No  250K   254.890965  Uplands
# ...           ...        ...     ...   ...   ...          ...      ...
# 53393         NaN        NaN     NaN  None  None          NaN     None
# 53397         NaN        NaN     NaN  None  None          NaN     None
# 53400         NaN        NaN     NaN  None  None          NaN     None
# 53402         NaN        NaN     NaN  None  None          NaN     None
# 53405         NaN        NaN     NaN  None  None          NaN     None
#
#          AREA_2  PERIMETER_2  LCCODE_2 Scale_2 Water         AreaM2  \
# 3           NaN          NaN       NaN    None  None            NaN
# 5           NaN          NaN       NaN    None  None            NaN
# 7           NaN          NaN       NaN    None  None            NaN
# 8           NaN          NaN       NaN    None  None            NaN
# 12          NaN          NaN       NaN    None  None            NaN
# ...         ...          ...       ...     ...   ...            ...
# 53393  18.13200     5562.890       6.1     50K    No  181319.774902
# 53397   4.64775      901.295       5.2     50K    No   46477.506836
# 53400   3.35118     1140.130       6.1     50K    No   33511.825684
# 53402   1.66341      558.113       5.1     50K    No   16634.142578
# 53405   4.62575      941.319       5.3     50K    No   46257.489258
#
#                                                 geometry
# 3      MULTIPOLYGON (((460463.250 1219243.875, 460450...
# 5      MULTIPOLYGON (((460242.281 1219003.250, 460219...
# 7      MULTIPOLYGON (((461668.219 1217595.375, 461575...
# 8      MULTIPOLYGON (((465491.062 1216859.625, 465609...
# 12     MULTIPOLYGON (((461097.656 1214307.250, 460997...
# ...                                                  ...
# 53393  MULTIPOLYGON (((213334.766 532438.438, 213335....
# 53397  MULTIPOLYGON (((212912.625 532135.688, 212941....
# 53400  MULTIPOLYGON (((211873.328 531991.875, 211867....
# 53402  MULTIPOLYGON (((214360.719 531267.375, 214346....
# 53405  MULTIPOLYGON (((214646.281 530799.938, 214637....
#
# [23521 rows x 14 columns]

# %% [markdown]
# ##### Run rasterization

# %%
# Run cat_polyrast
logpath = f'{interimFiles_path}polyrast/Agri_Scotland_polyrast_001.txt'
raster_path = f'{preppedDat_path}UKCEH_LC_2023_10m.tif'
poly_list = [agri1, agri2, agri3, agri4, agri5]

for i,j in enumerate(poly_list, start = 1):
    cat_polyrast(poly_path = poly_path , poly_select = j, cat_nr = i, raster_path = raster_path, logpath = logpath)
# Out:
# Polyrast Start 2025-02-04 00:09:07
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/LCA_50K_250K_union_1.tif.
#  Processing....
# Read ref raster Start 2025-02-04 00:09:07
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/UKCEH_LULC_10m.tif
# Read poly Start 2025-02-04 00:09:07
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/AgriculturalGrades/Scotland/LCA_50K_250K_union.gpkg
# Rasterize poly Start 2025-02-04 00:09:07
# Writing rasterized poly to file Start 2025-02-04 00:09:20
# Polyrast End 2025-02-04 00:10:00
# Polyras Code block run in 0:00:52.784075
#
# Polyrast Start 2025-02-04 00:10:00
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/LCA_50K_250K_union_2.tif.
#  Processing....
# Read ref raster Start 2025-02-04 00:10:00
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/UKCEH_LULC_10m.tif
# Read poly Start 2025-02-04 00:10:00
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/AgriculturalGrades/Scotland/LCA_50K_250K_union.gpkg
# Rasterize poly Start 2025-02-04 00:10:00
# Writing rasterized poly to file Start 2025-02-04 00:10:10
# Polyrast End 2025-02-04 00:10:48
# Polyras Code block run in 0:00:48.780501
#
# Polyrast Start 2025-02-04 00:10:48
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/LCA_50K_250K_union_3.tif.
#  Processing....
# Read ref raster Start 2025-02-04 00:10:48
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/UKCEH_LULC_10m.tif
# Read poly Start 2025-02-04 00:10:49
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/AgriculturalGrades/Scotland/LCA_50K_250K_union.gpkg
# Rasterize poly Start 2025-02-04 00:10:49
# Writing rasterized poly to file Start 2025-02-04 00:11:08
# Polyrast End 2025-02-04 00:11:46
# Polyras Code block run in 0:00:57.403552
#
# Polyrast Start 2025-02-04 00:11:46
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/LCA_50K_250K_union_4.tif.
#  Processing....
# Read ref raster Start 2025-02-04 00:11:46
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/UKCEH_LULC_10m.tif
# Read poly Start 2025-02-04 00:11:46
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/AgriculturalGrades/Scotland/LCA_50K_250K_union.gpkg
# Rasterize poly Start 2025-02-04 00:11:46
# Writing rasterized poly to file Start 2025-02-04 00:11:59
# Polyrast End 2025-02-04 00:12:39
# Polyras Code block run in 0:00:53.422120
#
# Polyrast Start 2025-02-04 00:12:39
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/LCA_50K_250K_union_5.tif.
#  Processing....
# Read ref raster Start 2025-02-04 00:12:39
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/UKCEH_LULC_10m.tif
# Read poly Start 2025-02-04 00:12:39
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/AgriculturalGrades/Scotland/LCA_50K_250K_union.gpkg
# Rasterize poly Start 2025-02-04 00:12:40
# Writing rasterized poly to file Start 2025-02-04 00:13:26
# Polyrast End 2025-02-04 00:14:07
# Polyras Code block run in 0:01:27.998537

# %% [markdown]
# #### Wales

# %%
poly_path = f'{rawDat_path}AgriculturalGrades/Wales/wg_predictive_alc2.gpkg'
poly_df = gpd.read_file(poly_path)

# %%
poly_df
# Out:
#         gridcode predictive                                           geometry
# 0            6.0          5  POLYGON ((238250.000 395900.000, 238150.000 39...
# 1            6.0          5  POLYGON ((227200.000 395100.000, 227150.000 39...
# 2            6.0          5  POLYGON ((227050.000 395050.000, 227050.000 39...
# 3            6.0          5  POLYGON ((227050.000 395050.000, 227050.000 39...
# 4            6.0          5  POLYGON ((227050.000 394950.000, 227100.000 39...
# ...          ...        ...                                                ...
# 254571       6.0          5  POLYGON ((321950.000 165000.000, 321900.000 16...
# 254572       4.0         3b  POLYGON ((322250.000 165000.000, 321950.000 16...
# 254573       6.0          5  POLYGON ((322250.000 165000.000, 322250.000 16...
# 254574       5.0          4  POLYGON ((336750.000 164650.000, 336650.000 16...
# 254575       4.0         3b  POLYGON ((332850.000 165900.000, 332850.000 16...
#
# [254576 rows x 3 columns]

# %%
poly_df['predictive'].unique()
# Out:
# array(['5', '3a', '4', '3b', '2', 'NA', 'U', '1'], dtype=object)

# %% [markdown]
# ##### Agri land 1

# %%
# Agri land 1
cat = 1
agri1 = poly_df.loc[poly_df['predictive'].isin([f'{cat}', f'{cat}a', f'{cat}b', f'{cat}c'])]
agri1
# Out:
#         gridcode predictive                                           geometry
# 1924         1.0          1  POLYGON ((276900.000 383800.000, 276800.000 38...
# 2162         1.0          1  POLYGON ((307800.000 383100.000, 307800.000 38...
# 2202         1.0          1  POLYGON ((307050.000 383050.000, 307050.000 38...
# 2224         1.0          1  POLYGON ((307700.000 382950.000, 307700.000 38...
# 2258         1.0          1  POLYGON ((307650.000 382900.000, 307600.000 38...
# ...          ...        ...                                                ...
# 253131       1.0          1  POLYGON ((317850.000 172750.000, 317700.000 17...
# 253154       1.0          1  POLYGON ((317550.000 172700.000, 317500.000 17...
# 253157       1.0          1  POLYGON ((318000.000 172800.000, 318100.000 17...
# 253188       1.0          1  POLYGON ((317650.000 172650.000, 317550.000 17...
# 253219       1.0          1  POLYGON ((318900.000 172550.000, 318900.000 17...
#
# [551 rows x 3 columns]

# %% [markdown]
# ##### Agri land 2

# %%
# Agri land 2
cat = 2
agri2 = poly_df.loc[poly_df['predictive'].isin([f'{cat}', f'{cat}a', f'{cat}b', f'{cat}c'])]
agri2
# Out:
#         gridcode predictive                                           geometry
# 20           2.0          2  POLYGON ((239500.000 394400.000, 239400.000 39...
# 25           2.0          2  POLYGON ((239550.000 394350.000, 239500.000 39...
# 31           2.0          2  POLYGON ((239600.000 394300.000, 239550.000 39...
# 45           2.0          2  POLYGON ((239650.000 394250.000, 239600.000 39...
# 58           2.0          2  POLYGON ((239700.000 394200.000, 239650.000 39...
# ...          ...        ...                                                ...
# 254252       2.0          2  POLYGON ((302900.000 167500.000, 302800.000 16...
# 254262       2.0          2  POLYGON ((296850.000 167800.000, 296950.000 16...
# 254405       2.0          2  POLYGON ((299400.000 166550.000, 299300.000 16...
# 254423       2.0          2  POLYGON ((299650.000 166500.000, 299650.000 16...
# 254434       2.0          2  POLYGON ((300450.000 166450.000, 300400.000 16...
#
# [9699 rows x 3 columns]

# %% [markdown]
# ##### Agri land 3

# %%
# Agri land 3
cat = 3
agri3 = poly_df.loc[poly_df['predictive'].isin([f'{cat}', f'{cat}a', f'{cat}b', f'{cat}c'])]
agri3
# Out:
#         gridcode predictive                                           geometry
# 6            3.0         3a  POLYGON ((226800.000 394750.000, 226750.000 39...
# 10           4.0         3b  POLYGON ((237450.000 394550.000, 237300.000 39...
# 21           3.0         3a  POLYGON ((239550.000 394400.000, 239500.000 39...
# 27           4.0         3b  POLYGON ((241400.000 394350.000, 241350.000 39...
# 29           3.0         3a  POLYGON ((238100.000 394400.000, 238200.000 39...
# ...          ...        ...                                                ...
# 254563       3.0         3a  POLYGON ((302600.000 165700.000, 302600.000 16...
# 254564       4.0         3b  POLYGON ((307100.000 165700.000, 307000.000 16...
# 254566       3.0         3a  POLYGON ((302400.000 165650.000, 302400.000 16...
# 254572       4.0         3b  POLYGON ((322250.000 165000.000, 321950.000 16...
# 254575       4.0         3b  POLYGON ((332850.000 165900.000, 332850.000 16...
#
# [71834 rows x 3 columns]

# %% [markdown]
# ##### Agri land 4

# %%
# Agri land 4
cat = 4
agri4 = poly_df.loc[poly_df['predictive'].isin([f'{cat}', f'{cat}a', f'{cat}b', f'{cat}c'])]
agri4
# Out:
#         gridcode predictive                                           geometry
# 7            5.0          4  POLYGON ((239400.000 394750.000, 239400.000 39...
# 15           5.0          4  POLYGON ((239650.000 394450.000, 239550.000 39...
# 16           5.0          4  POLYGON ((240900.000 394450.000, 240850.000 39...
# 23           5.0          4  POLYGON ((240200.000 394400.000, 240150.000 39...
# 39           5.0          4  POLYGON ((282000.000 323050.000, 281900.000 32...
# ...          ...        ...                                                ...
# 254555       5.0          4  POLYGON ((332550.000 165900.000, 332400.000 16...
# 254557       5.0          4  POLYGON ((332850.000 165900.000, 332650.000 16...
# 254568       5.0          4  POLYGON ((336800.000 165350.000, 336450.000 16...
# 254569       5.0          4  POLYGON ((334850.000 165300.000, 334550.000 16...
# 254574       5.0          4  POLYGON ((336750.000 164650.000, 336650.000 16...
#
# [64628 rows x 3 columns]

# %% [markdown]
# ##### Agri land 5+

# %%
# Agri land 5
cat = 5
agri5 = poly_df.loc[poly_df['predictive'].isin([f'{cat}', f'{cat}a', f'{cat}b', f'{cat}c'])]
agri5
# Out:
#         gridcode predictive                                           geometry
# 0            6.0          5  POLYGON ((238250.000 395900.000, 238150.000 39...
# 1            6.0          5  POLYGON ((227200.000 395100.000, 227150.000 39...
# 2            6.0          5  POLYGON ((227050.000 395050.000, 227050.000 39...
# 3            6.0          5  POLYGON ((227050.000 395050.000, 227050.000 39...
# 4            6.0          5  POLYGON ((227050.000 394950.000, 227100.000 39...
# ...          ...        ...                                                ...
# 254558       6.0          5  POLYGON ((303450.000 165850.000, 303300.000 16...
# 254561       6.0          5  POLYGON ((305900.000 165750.000, 305850.000 16...
# 254570       6.0          5  POLYGON ((321950.000 165050.000, 321950.000 16...
# 254571       6.0          5  POLYGON ((321950.000 165000.000, 321900.000 16...
# 254573       6.0          5  POLYGON ((322250.000 165000.000, 322250.000 16...
#
# [38823 rows x 3 columns]

# %% [markdown]
# ##### Run rasterization

# %%
# Run cat_polyrast
logpath = f'{interimFiles_path}polyrast/Agri_Wales_polyrast_001.txt'
raster_path = f'{preppedDat_path}UKCEH_LC_2023_10m.tif'
poly_list = [agri1, agri2, agri3, agri4, agri5]

for i,j in enumerate(poly_list, start = 1):
    cat_polyrast(poly_path = poly_path , poly_select = j, cat_nr = i, raster_path = raster_path, logpath = logpath)
# Out:
# Polyrast Start 2025-02-04 00:14:57
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/wg_predictive_alc2_1.tif.
#  Processing....
# Read ref raster Start 2025-02-04 00:14:57
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/UKCEH_LULC_10m.tif
# Read poly Start 2025-02-04 00:14:57
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/AgriculturalGrades/Wales/wg_predictive_alc2.gpkg
# Rasterize poly Start 2025-02-04 00:14:57
# Writing rasterized poly to file Start 2025-02-04 00:15:03
# Polyrast End 2025-02-04 00:15:49
# Polyras Code block run in 0:00:51.786063
#
# Polyrast Start 2025-02-04 00:15:49
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/wg_predictive_alc2_2.tif.
#  Processing....
# Read ref raster Start 2025-02-04 00:15:49
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/UKCEH_LULC_10m.tif
# Read poly Start 2025-02-04 00:15:49
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/AgriculturalGrades/Wales/wg_predictive_alc2.gpkg
# Rasterize poly Start 2025-02-04 00:15:49
# Writing rasterized poly to file Start 2025-02-04 00:16:01
# Polyrast End 2025-02-04 00:16:42
# Polyras Code block run in 0:00:53.276468
#
# Polyrast Start 2025-02-04 00:16:42
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/wg_predictive_alc2_3.tif.
#  Processing....
# Read ref raster Start 2025-02-04 00:16:42
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/UKCEH_LULC_10m.tif
# Read poly Start 2025-02-04 00:16:42
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/AgriculturalGrades/Wales/wg_predictive_alc2.gpkg
# Rasterize poly Start 2025-02-04 00:16:43
# Writing rasterized poly to file Start 2025-02-04 00:17:06
# Polyrast End 2025-02-04 00:17:46
# Polyras Code block run in 0:01:03.504342
#
# Polyrast Start 2025-02-04 00:17:46
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/wg_predictive_alc2_4.tif.
#  Processing....
# Read ref raster Start 2025-02-04 00:17:46
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/UKCEH_LULC_10m.tif
# Read poly Start 2025-02-04 00:17:46
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/AgriculturalGrades/Wales/wg_predictive_alc2.gpkg
# Rasterize poly Start 2025-02-04 00:17:46
# Writing rasterized poly to file Start 2025-02-04 00:18:07
# Polyrast End 2025-02-04 00:19:00
# Polyras Code block run in 0:01:13.903572
#
# Polyrast Start 2025-02-04 00:19:00
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/wg_predictive_alc2_5.tif.
#  Processing....
# Read ref raster Start 2025-02-04 00:19:00
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/UKCEH_LULC_10m.tif
# Read poly Start 2025-02-04 00:19:00
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/AgriculturalGrades/Wales/wg_predictive_alc2.gpkg
# Rasterize poly Start 2025-02-04 00:19:00
# Writing rasterized poly to file Start 2025-02-04 00:19:17
# Polyrast End 2025-02-04 00:20:02
# Polyras Code block run in 0:01:02.806591

# %% [markdown]
# #### England

# %%
poly_path = f'{rawDat_path}AgriculturalGrades/England/England_ALC.gpkg'
poly_df = gpd.read_file(poly_path)

# %%
poly_df
# Out:
#      GEOGEXT        AREA         ALC_GRADE   PERIMETER  \
# 0        TG2   3712.5350           Grade 1   69726.523
# 1        TG2  14694.1436           Grade 2  353091.649
# 2        TG2   9606.3941           Grade 3  324491.005
# 3        TG2    852.6170           Grade 4   54877.723
# 4        TG2   1371.9177  Non Agricultural   95549.247
# ...      ...         ...               ...         ...
# 1821    None         NaN             Urban         NaN
# 1822    None         NaN           Grade 4         NaN
# 1823    None         NaN           Grade 2         NaN
# 1824    None         NaN           Grade 2         NaN
# 1825    None         NaN           Grade 2         NaN
#
#                                                geometry
# 0     MULTIPOLYGON (((607170.000 230840.000, 607080....
# 1     MULTIPOLYGON (((598336.077 221689.728, 598380....
# 2     MULTIPOLYGON (((616613.668 224182.664, 616610....
# 3     MULTIPOLYGON (((623990.000 229210.000, 624020....
# 4     MULTIPOLYGON (((624176.448 232699.493, 624110....
# ...                                                 ...
# 1821  MULTIPOLYGON (((91404.214 10181.069, 91480.418...
# 1822  MULTIPOLYGON (((90611.398 11793.825, 90648.821...
# 1823  MULTIPOLYGON (((89849.310 10091.251, 89905.223...
# 1824  MULTIPOLYGON (((91543.688 10769.655, 91518.380...
# 1825  MULTIPOLYGON (((90986.911 10092.666, 91075.489...
#
# [1826 rows x 5 columns]

# %%
poly_df['ALC_GRADE'].unique()
# Out:
# array(['Grade 1', 'Grade 2', 'Grade 3', 'Grade 4', 'Non Agricultural',
#        'Urban', 'Grade 5', 'Exclusion'], dtype=object)

# %% [markdown]
# ##### Agri land 1

# %%
# Agri land 1
cat = 1
agri1 = poly_df.loc[poly_df['ALC_GRADE'] == f'Grade {cat}']
agri1
# Out:
#      GEOGEXT       AREA ALC_GRADE  PERIMETER  \
# 0        TG2  3712.5350   Grade 1  69726.523
# 6        TG2   423.6100   Grade 1  21323.943
# 16       T2V   543.3005   Grade 1  15973.449
# 32       6G2     0.2891   Grade 1    685.536
# 33       6G2     0.1089   Grade 1    270.058
# ...      ...        ...       ...        ...
# 1717     E87   902.6960   Grade 1  47622.797
# 1728     E87   569.2199   Grade 1  32552.736
# 1815    None        NaN   Grade 1        NaN
# 1816    None        NaN   Grade 1        NaN
# 1817    None        NaN   Grade 1        NaN
#
#                                                geometry
# 0     MULTIPOLYGON (((607170.000 230840.000, 607080....
# 6     MULTIPOLYGON (((618970.000 238330.000, 618900....
# 16    MULTIPOLYGON (((650202.458 298181.151, 650250....
# 32    MULTIPOLYGON (((586438.880 188536.079, 586479....
# 33    MULTIPOLYGON (((591421.288 187543.231, 591433....
# ...                                                 ...
# 1717  MULTIPOLYGON (((416737.196 239744.391, 416740....
# 1728  MULTIPOLYGON (((406140.000 246860.000, 406050....
# 1815  MULTIPOLYGON (((89255.670 14756.106, 89279.483...
# 1816  MULTIPOLYGON (((89065.170 14689.960, 88985.794...
# 1817  MULTIPOLYGON (((89398.545 14412.676, 89454.108...
#
# [124 rows x 5 columns]

# %% [markdown]
# ##### Agri land 2

# %%
# Agri land 2
cat = 2
agri2 = poly_df.loc[poly_df['ALC_GRADE'] == f'Grade {cat}']
agri2
# Out:
#      GEOGEXT        AREA ALC_GRADE   PERIMETER  \
# 1        TG2  14694.1436   Grade 2  353091.649
# 7        TG2   9051.9062   Grade 2  184437.084
# 12       T2V   1719.9463   Grade 2   37044.450
# 17       T2V   7172.2453   Grade 2  259009.258
# 34       62W    260.0530   Grade 2   10505.352
# ...      ...         ...       ...         ...
# 1814    None         NaN   Grade 2         NaN
# 1818    None         NaN   Grade 2         NaN
# 1823    None         NaN   Grade 2         NaN
# 1824    None         NaN   Grade 2         NaN
# 1825    None         NaN   Grade 2         NaN
#
#                                                geometry
# 1     MULTIPOLYGON (((598336.077 221689.728, 598380....
# 7     MULTIPOLYGON (((610053.515 241599.455, 610060....
# 12    MULTIPOLYGON (((638912.303 296984.627, 638970....
# 17    MULTIPOLYGON (((609723.984 269330.000, 609800....
# 34    MULTIPOLYGON (((477266.348 220498.471, 477320....
# ...                                                 ...
# 1814  MULTIPOLYGON (((89790.129 14753.460, 89835.109...
# 1818  MULTIPOLYGON (((91058.809 9579.523, 91090.559 ...
# 1823  MULTIPOLYGON (((89849.310 10091.251, 89905.223...
# 1824  MULTIPOLYGON (((91543.688 10769.655, 91518.380...
# 1825  MULTIPOLYGON (((90986.911 10092.666, 91075.489...
#
# [255 rows x 5 columns]

# %% [markdown]
# ##### Agri land 3

# %%
# Agri land 3
cat = 3
agri3 = poly_df.loc[poly_df['ALC_GRADE'] == f'Grade {cat}']
agri3
# Out:
#      GEOGEXT        AREA ALC_GRADE   PERIMETER  \
# 2        TG2   9606.3941   Grade 3  324491.005
# 8        TG2   8711.7056   Grade 3  249911.345
# 13       T2V   7236.6201   Grade 3  100310.828
# 18       T2V  48286.0523   Grade 3  425273.609
# 23       6G2      0.2504   Grade 3     607.908
# ...      ...         ...       ...         ...
# 1743      81  37774.8472   Grade 3  471217.724
# 1748      81  18679.1934   Grade 3  146661.401
# 1752      81  33105.9249   Grade 3  555723.965
# 1757      81  40696.5267   Grade 3  612770.571
# 1762      81    128.2883   Grade 3   10244.057
#
#                                                geometry
# 2     MULTIPOLYGON (((616613.668 224182.664, 616610....
# 8     MULTIPOLYGON (((622740.819 242716.658, 622730....
# 13    MULTIPOLYGON (((643684.105 297785.848, 643750....
# 18    MULTIPOLYGON (((645190.000 290970.000, 645010....
# 23    MULTIPOLYGON (((576643.501 189512.622, 576867....
# ...                                                 ...
# 1743  MULTIPOLYGON (((436910.321 318515.924, 436780....
# 1748  MULTIPOLYGON (((464108.931 280895.843, 464070....
# 1752  MULTIPOLYGON (((399883.590 336984.663, 399910....
# 1757  MULTIPOLYGON (((443564.786 262012.393, 443600....
# 1762  MULTIPOLYGON (((437686.080 282700.000, 437800....
#
# [365 rows x 5 columns]

# %% [markdown]
# ##### Agri land 4

# %%
# Agri land 4
cat = 4
agri4 = poly_df.loc[poly_df['ALC_GRADE'] == f'Grade {cat}']
agri4
# Out:
#      GEOGEXT       AREA ALC_GRADE   PERIMETER  \
# 3        TG2   852.6170   Grade 4   54877.723
# 9        TG2  1938.8302   Grade 4   81416.241
# 14       T2V   996.7846   Grade 4   55628.099
# 19       T2V  2542.1704   Grade 4  125462.465
# 36       62W   516.0684   Grade 4   23969.161
# ...      ...        ...       ...         ...
# 1808    None        NaN   Grade 4         NaN
# 1809    None        NaN   Grade 4         NaN
# 1810    None        NaN   Grade 4         NaN
# 1811    None        NaN   Grade 4         NaN
# 1822    None        NaN   Grade 4         NaN
#
#                                                geometry
# 3     MULTIPOLYGON (((623990.000 229210.000, 624020....
# 9     MULTIPOLYGON (((621441.498 242565.364, 621410....
# 14    MULTIPOLYGON (((640061.615 291367.747, 640100....
# 19    MULTIPOLYGON (((629158.653 286154.264, 629310....
# 36    MULTIPOLYGON (((476564.243 215871.888, 476590....
# ...                                                 ...
# 1808  MULTIPOLYGON (((92151.080 11029.062, 92144.753...
# 1809  MULTIPOLYGON (((91954.943 12117.307, 92068.829...
# 1810  MULTIPOLYGON (((91480.418 10061.031, 91550.015...
# 1811  MULTIPOLYGON (((89904.959 10264.530, 90012.553...
# 1822  MULTIPOLYGON (((90611.398 11793.825, 90648.821...
#
# [332 rows x 5 columns]

# %% [markdown]
# ##### Agri land 5+

# %%
# Agri land 5
cat = 5
agri5 = poly_df.loc[poly_df['ALC_GRADE'] == f'Grade {cat}']
agri5
# Out:
#      GEOGEXT      AREA ALC_GRADE  PERIMETER  \
# 41        6K  554.0400   Grade 5  39847.852
# 48        6K    5.3878   Grade 5    994.672
# 71        58  139.7900   Grade 5   5399.381
# 79        58  126.9399   Grade 5   9882.578
# 92        A7   73.2575   Grade 5   4613.164
# ...      ...       ...       ...        ...
# 1785    None       NaN   Grade 5        NaN
# 1786    None       NaN   Grade 5        NaN
# 1787    None       NaN   Grade 5        NaN
# 1797    None       NaN   Grade 5        NaN
# 1798    None       NaN   Grade 5        NaN
#
#                                                geometry
# 41    MULTIPOLYGON (((595440.000 170400.000, 595410....
# 48    MULTIPOLYGON (((575057.189 168478.704, 575120....
# 71    MULTIPOLYGON (((350350.000 353770.000, 350240....
# 79    MULTIPOLYGON (((347407.784 333829.446, 347410....
# 92    MULTIPOLYGON (((404156.800 94848.093, 404270.0...
# ...                                                 ...
# 1785  MULTIPOLYGON (((88850.592 8167.174, 88892.926 ...
# 1786  MULTIPOLYGON (((87445.652 8069.278, 87427.131 ...
# 1787  MULTIPOLYGON (((88104.466 7521.589, 88138.862 ...
# 1797  MULTIPOLYGON (((87818.980 8690.256, 87853.376 ...
# 1798  MULTIPOLYGON (((87340.083 8505.047, 87369.187 ...
#
# [196 rows x 5 columns]

# %% [markdown]
# ##### Run rasterization

# %%
# Run cat_polyrast
logpath = f'{interimFiles_path}polyrast/Agri_England_polyrast_001.txt'
raster_path = f'{preppedDat_path}UKCEH_LC_2023_10m.tif'
poly_list = [agri1, agri2, agri3, agri4, agri5]

for i,j in enumerate(poly_list, start = 1):
    cat_polyrast(poly_path = poly_path , poly_select = j, cat_nr = i, raster_path = raster_path, logpath = logpath)
# Out:
# Polyrast Start 2025-02-04 00:20:15
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/England_ALC_1.tif.
#  Processing....
# Read ref raster Start 2025-02-04 00:20:15
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/UKCEH_LULC_10m.tif
# Read poly Start 2025-02-04 00:20:15
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/AgriculturalGrades/England/England_ALC.gpkg
# Rasterize poly Start 2025-02-04 00:20:15
# Writing rasterized poly to file Start 2025-02-04 00:20:22
# Polyrast End 2025-02-04 00:21:08
# Polyras Code block run in 0:00:52.964614
#
# Polyrast Start 2025-02-04 00:21:08
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/England_ALC_2.tif.
#  Processing....
# Read ref raster Start 2025-02-04 00:21:08
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/UKCEH_LULC_10m.tif
# Read poly Start 2025-02-04 00:21:08
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/AgriculturalGrades/England/England_ALC.gpkg
# Rasterize poly Start 2025-02-04 00:21:08
# Writing rasterized poly to file Start 2025-02-04 00:21:19
# Polyrast End 2025-02-04 00:22:08
# Polyras Code block run in 0:00:59.569413
#
# Polyrast Start 2025-02-04 00:22:08
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/England_ALC_3.tif.
#  Processing....
# Read ref raster Start 2025-02-04 00:22:08
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/UKCEH_LULC_10m.tif
# Read poly Start 2025-02-04 00:22:08
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/AgriculturalGrades/England/England_ALC.gpkg
# Rasterize poly Start 2025-02-04 00:22:08
# Writing rasterized poly to file Start 2025-02-04 00:22:26
# Polyrast End 2025-02-04 00:23:11
# Polyras Code block run in 0:01:03.300396
#
# Polyrast Start 2025-02-04 00:23:11
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/England_ALC_4.tif.
#  Processing....
# Read ref raster Start 2025-02-04 00:23:11
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/UKCEH_LULC_10m.tif
# Read poly Start 2025-02-04 00:23:11
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/AgriculturalGrades/England/England_ALC.gpkg
# Rasterize poly Start 2025-02-04 00:23:11
# Writing rasterized poly to file Start 2025-02-04 00:23:23
# Polyrast End 2025-02-04 00:24:20
# Polyras Code block run in 0:01:09.442395
#
# Polyrast Start 2025-02-04 00:24:20
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/England_ALC_5.tif.
#  Processing....
# Read ref raster Start 2025-02-04 00:24:20
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_for_mcdm/UKCEH_LULC_10m.tif
# Read poly Start 2025-02-04 00:24:21
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/AgriculturalGrades/England/England_ALC.gpkg
# Rasterize poly Start 2025-02-04 00:24:21
# Writing rasterized poly to file Start 2025-02-04 00:24:30
# Polyrast End 2025-02-04 00:25:15
# Polyras Code block run in 0:00:54.863513

# %% [markdown]
# #### Merge countries by category

# %%
for i in range(1,6):
    write_path = f'{preppedDat_path}AgriGrades/UK_ALC_cat{i}.tif'
    eng_path = f'{preppedDat_path}AgriGrades/England_ALC_{i}.tif'
    sco_path = f'{preppedDat_path}AgriGrades/LCA_50K_250K_union_{i}.tif'
    wal_path = f'{preppedDat_path}AgriGrades/wg_predictive_alc2_{i}.tif'
    
    with rio.open(eng_path) as src_eng:
        dask_ar_eng = da.from_array(src_eng.read(1), chunks= 100)
    
    with rio.open(sco_path) as src_sco:
        dask_ar_sco = da.from_array(src_sco.read(1), chunks= 100)
    
        # Merging eng-sco
        logmsk = f'Merge Eng-Sco\n Mask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
        print(logmsk)
        mask = dask_ar_eng > 0 # Make a boolean array out of non-null raster pixels
        logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
        print(logdifst)
        processed_data = da.where(mask, 1, dask_ar_sco) #Pixels in mask set to 1        
        logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge cat {i} complete.'
        print(logdif)
        # Merging result - wal
        with rio.open(wal_path) as src_wal:
            dask_ar_wal = da.from_array(src_wal.read(1), chunks= 100)
        logmsk = f'Merge result-Wal\n Mask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
        print(logmsk)
        mask = processed_data > 0 # Make a boolean array out of non-null raster pixels
        logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
        print(logdifst)
        processed_data = da.where(mask, 1, dask_ar_wal) #Pixels in mask set to 1       
        logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge cat {i} complete.'
        print(logdif)
        # Write result to file
        with rio.open(
            write_path, 'w',
            driver='GTiff',
            height=processed_data.shape[0],
            width=processed_data.shape[1],
            count=1,
            dtype=processed_data.dtype,
            crs=src_eng.crs,
            transform=src_eng.transform,
            compress='DEFLATE'
        ) as dst:
            dst.write(processed_data.compute(), 1)

        logwri = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge cat {i} written to file.'
        print(logwri)
# Out:
# Merge Eng-Sco
#  Mask creation Start 2025-02-05 00:44:33
# Merge Start 2025-02-05 00:44:33
# 2025-02-05 00:44:33 - Merge cat 1 complete.
# Merge result-Wal
#  Mask creation Start 2025-02-05 00:45:00
# Merge Start 2025-02-05 00:45:00
# 2025-02-05 00:45:00 - Merge cat 1 complete.
# 2025-02-05 00:57:58 - Merge cat 1 written to file.
# Merge Eng-Sco
#  Mask creation Start 2025-02-05 00:58:59
# Merge Start 2025-02-05 00:58:59
# 2025-02-05 00:59:04 - Merge cat 2 complete.
# Merge result-Wal
#  Mask creation Start 2025-02-05 00:59:39
# Merge Start 2025-02-05 00:59:39
# 2025-02-05 00:59:39 - Merge cat 2 complete.
# 2025-02-05 01:13:24 - Merge cat 2 written to file.
# Merge Eng-Sco
#  Mask creation Start 2025-02-05 01:14:18
# Merge Start 2025-02-05 01:14:18
# 2025-02-05 01:14:22 - Merge cat 3 complete.
# Merge result-Wal
#  Mask creation Start 2025-02-05 01:14:48
# Merge Start 2025-02-05 01:14:48
# 2025-02-05 01:14:48 - Merge cat 3 complete.
# 2025-02-05 01:27:51 - Merge cat 3 written to file.
# Merge Eng-Sco
#  Mask creation Start 2025-02-05 01:28:43
# Merge Start 2025-02-05 01:28:44
# 2025-02-05 01:28:48 - Merge cat 4 complete.
# Merge result-Wal
#  Mask creation Start 2025-02-05 01:29:16
# Merge Start 2025-02-05 01:29:16
# 2025-02-05 01:29:16 - Merge cat 4 complete.
# 2025-02-05 01:42:29 - Merge cat 4 written to file.
# Merge Eng-Sco
#  Mask creation Start 2025-02-05 01:43:23
# Merge Start 2025-02-05 01:43:23
# 2025-02-05 01:43:28 - Merge cat 5 complete.
# Merge result-Wal
#  Mask creation Start 2025-02-05 01:43:57
# Merge Start 2025-02-05 01:43:57
# 2025-02-05 01:43:57 - Merge cat 5 complete.
# 2025-02-05 01:57:33 - Merge cat 5 written to file.

# %% [markdown]
# #### Merge all categories (for agristats)

# %% [markdown]
# Doing all 5 layers at once runs out of memory. So does QGIS when using conditional raster operations (addition/multiplication works fine but I'm getting overlap issues, and also it saves in 32 bit format so needs extra recompression after)
# --> Doing it in several steps here

# %%
# Layer 4 atop of 5
write_path = f'{preppedDat_path}Agrigrades/UK_ALC_4-5.tif'
path1 = f'{preppedDat_path}Agrigrades/UK_ALC_cat5.tif'
path2 = f'{preppedDat_path}Agrigrades/UK_ALC_cat4.tif'

with rio.open(path1) as src_1:
    dask_ar_1 = da.from_array(src_1.read(1), chunks= 100)

with rio.open(path2) as src_2:
    dask_ar_2 = da.from_array(src_2.read(1), chunks= 100)

    # Merging 2-1
    logmsk = f'Merge 2-1\nMask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logmsk)
    mask = dask_ar_2 > 0 # Make a boolean array out of non-null raster pixels
    logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logdifst)
    processed_data = da.where(mask, 4, dask_ar_1*5)     
    logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge 1-2 complete.'
    print(logdif)
    
    # Write result to file
    with rio.open(
        write_path, 'w',
        driver='GTiff',
        height=processed_data.shape[0],
        width=processed_data.shape[1],
        count=1,
        dtype=processed_data.dtype,
        crs=src_1.crs,
        transform=src_1.transform,
        compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

    logwri = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge final result written to file.'
    print(logwri)
# Out:
# Merge 2-1
# Mask creation Start 2025-03-11 12:46:38
# Merge Start 2025-03-11 12:46:38
# 2025-03-11 12:46:38 - Merge 1-2 complete.
# 2025-03-11 12:57:37 - Merge final result written to file.

# %%
# Layer 2 atop of 3
write_path = f'{preppedDat_path}Agrigrades/UK_ALC_2-3.tif'
path1 = f'{preppedDat_path}Agrigrades/UK_ALC_cat3.tif'
path2 = f'{preppedDat_path}Agrigrades/UK_ALC_cat2.tif'

with rio.open(path1) as src_1:
    dask_ar_1 = da.from_array(src_1.read(1), chunks= 100)

with rio.open(path2) as src_2:
    dask_ar_2 = da.from_array(src_2.read(1), chunks= 100)

    # Merging 2-1
    logmsk = f'Merge 2-1\nMask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logmsk)
    mask = dask_ar_2 > 0 # Make a boolean array out of non-null raster pixels
    logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logdifst)
    processed_data = da.where(mask, 2, dask_ar_1*3)     
    logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge 1-2 complete.'
    print(logdif)
    
    # Write result to file
    with rio.open(
        write_path, 'w',
        driver='GTiff',
        height=processed_data.shape[0],
        width=processed_data.shape[1],
        count=1,
        dtype=processed_data.dtype,
        crs=src_1.crs,
        transform=src_1.transform,
        compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

    logwri = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge final result written to file.'
    print(logwri)
# Out:
# Merge 2-1
# Mask creation Start 2025-03-11 12:58:37
# Merge Start 2025-03-11 12:58:37
# 2025-03-11 12:58:40 - Merge 1-2 complete.
# 2025-03-11 13:09:06 - Merge final result written to file.

# %%
# Layer 2-3 atop of 4-5
write_path = f'{preppedDat_path}Agrigrades/UK_ALC_2-3-4-5.tif'
path1 = f'{preppedDat_path}Agrigrades/UK_ALC_4-5.tif'
path2 = f'{preppedDat_path}Agrigrades/UK_ALC_2-3.tif'

with rio.open(path1) as src_1:
    dask_ar_1 = da.from_array(src_1.read(1), chunks= 100)

with rio.open(path2) as src_2:
    dask_ar_2 = da.from_array(src_2.read(1), chunks= 100)

    # Merging 2-1
    logmsk = f'Merge 2-1\nMask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logmsk)
    mask = dask_ar_2 > 0 # Make a boolean array out of non-null raster pixels
    logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logdifst)
    processed_data = da.where(mask, dask_ar_2, dask_ar_1)     
    logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge 1-2 complete.'
    print(logdif)
    
    # Write result to file
    with rio.open(
        write_path, 'w',
        driver='GTiff',
        height=processed_data.shape[0],
        width=processed_data.shape[1],
        count=1,
        dtype=processed_data.dtype,
        crs=src_1.crs,
        transform=src_1.transform,
        compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

    logwri = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge final result written to file.'
    print(logwri)
# Out:
# Merge 2-1
# Mask creation Start 2025-03-11 13:09:57
# Merge Start 2025-03-11 13:09:58
# 2025-03-11 13:10:03 - Merge 1-2 complete.
# 2025-03-11 13:20:40 - Merge final result written to file.

# %%
# Layer 1 atop of 2-3-4-5
write_path = f'{preppedDat_path}Agrigrades/UK_ALC_all_cat.tif'
path1 = f'{preppedDat_path}Agrigrades/UK_ALC_2-3-4-5.tif'
path2 = f'{preppedDat_path}Agrigrades/UK_ALC_cat1.tif'

with rio.open(path1) as src_1:
    dask_ar_1 = da.from_array(src_1.read(1), chunks= 100)

with rio.open(path2) as src_2:
    dask_ar_2 = da.from_array(src_2.read(1), chunks= 100)

    # Merging 2-1
    logmsk = f'Merge 2-1\nMask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logmsk)
    mask = dask_ar_2 > 0 # Make a boolean array out of non-null raster pixels
    logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logdifst)
    processed_data = da.where(mask, dask_ar_2, dask_ar_1)     
    logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge 1-2 complete.'
    print(logdif)
    
    # Write result to file
    with rio.open(
        write_path, 'w',
        driver='GTiff',
        height=processed_data.shape[0],
        width=processed_data.shape[1],
        count=1,
        dtype=processed_data.dtype,
        crs=src_1.crs,
        transform=src_1.transform,
        compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

    logwri = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge final result written to file.'
    print(logwri)
# Out:
# Merge 2-1
# Mask creation Start 2025-03-11 14:06:08
# Merge Start 2025-03-11 14:06:08
# 2025-03-11 14:06:08 - Merge 1-2 complete.
# 2025-03-11 14:29:41 - Merge final result written to file.

# %% [markdown]
# ### Substations

# %%
poly_path = f'{preppedDat_path}substations_Lovett2022.gpkg'
logpath = f'{interimFiles_path}polyrast/Substations_polyrast_001.txt'
raster_path = f'{preppedDat_path}UKCEH_LC_2023_10m.tif'

# %%
polyrast(poly_path, raster_path, logpath)
# Out:
# Polyrast Start 2025-02-06 00:06:49
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/substations_Lovett2022.tif.
#  Processing....
# Read ref raster Start 2025-02-06 00:06:49
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/UKCEH_LC_2023_10m.tif
# Read poly Start 2025-02-06 00:06:49
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/substations_Lovett2022.gpkg
# Rasterize poly Start 2025-02-06 00:06:51
# Writing rasterized poly to file Start 2025-02-06 00:07:04
# Polyrast End 2025-02-06 00:07:45
# Polyras Code block run in 0:00:55.775472
# 'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/substations_Lovett2022.tif'

# %% [markdown]
# ### Rasterize former poly layers (4/03)

# %%
# Getting paths of all remaining poly layers
xl_path = f'{workFiles_path}/versions/Parameters_017.xlsx' # Last version of the Excel tables that had the poly layers
table = pd.read_excel(xl_path, sheet_name = 'Suitability factors')
poly_df = table.loc[table['type']=='poly']
poly_pointline_df = poly_df.loc[poly_df['Prepped Path'].str.contains('point|line', case = False, na = False)] # Separating point and line layers for different processing
poly_pointline_paths = poly_pointline_df['Prepped Path'].unique()
poly_only_df = poly_df.loc[~poly_df['Prepped Path'].str.contains('point|line', case = False, na = False)] # Inverse of the condition above
poly_only_paths = poly_only_df['Prepped Path'].unique()
# In the end because even on the poly layers many have very small geometries, I decide to process all with all_touched = True instead of separating points/lines and poly
poly_paths = poly_df['Prepped Path'].unique()
poly_paths
# Out:
# array(['C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/global_wind_2020_point_cropped.gpkg',
#        'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/global_solar_2020_point_cropped.gpkg',
#        'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/global_solar_2020_poly_cropped.gpkg',
#        'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/OS_open_roads_lines.gpkg',
#        'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/Airports/hotosm_gbr_airports_points_gpkg.gpkg',
#        'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/Study_area_basedOn_UK_BFC_EPSG27700.gpkg',
#        'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/OS_open_rivers_lines.gpkg',
#        'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/Heritage_Listed_Buildings_poly.gpkg',
#        'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/Heritage_Listed_Buildings_points.gpkg',
#        'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/Heritage_Parks_Gardens.gpkg',
#        'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/Heritage_Monuments.gpkg',
#        'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/Heritage_WHS_Battlefields.gpkg'],
#       dtype=object)

# %%
raster_path = f'{preppedDat_path}UKCEH_LC_2023_10m.tif'

for i, j in enumerate(poly_paths):
    logpath = f'{interimFiles_path}polyrast/logs/LastPolys_polyrast_{i}.txt'    
    polyrast(j, raster_path, logpath, all_touched=True)
# Out:
# Polyrast Start 2025-03-04 17:10:22
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/global_wind_2020_point_cropped.tif.
#  Processing....
# Read ref raster Start 2025-03-04 17:10:22
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/UKCEH_LC_2023_10m.tif
# Read poly Start 2025-03-04 17:10:22
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/global_wind_2020_point_cropped.gpkg
# Rasterize poly Start 2025-03-04 17:10:23
# Writing rasterized poly to file Start 2025-03-04 17:10:35
# Polyrast End 2025-03-04 17:11:26
# Polyras Code block run in 0:01:03.852487
#
# Polyrast Start 2025-03-04 17:11:26
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/global_solar_2020_point_cropped.tif.
#  Processing....
# Read ref raster Start 2025-03-04 17:11:26
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/UKCEH_LC_2023_10m.tif
# Read poly Start 2025-03-04 17:11:26
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/global_solar_2020_point_cropped.gpkg
# Rasterize poly Start 2025-03-04 17:11:32
# Writing rasterized poly to file Start 2025-03-04 17:11:43
# Polyrast End 2025-03-04 17:12:24
# Polyras Code block run in 0:00:58.303319
#
# Polyrast Start 2025-03-04 17:12:24
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/global_solar_2020_poly_cropped.tif.
#  Processing....
# Read ref raster Start 2025-03-04 17:12:24
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/UKCEH_LC_2023_10m.tif
# Read poly Start 2025-03-04 17:12:24
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/global_solar_2020_poly_cropped.gpkg
# Rasterize poly Start 2025-03-04 17:12:26
# Writing rasterized poly to file Start 2025-03-04 17:12:34
# Polyrast End 2025-03-04 17:13:13
# Polyras Code block run in 0:00:49.132844
#
# Polyrast Start 2025-03-04 17:13:13
# File already exists: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/OS_open_roads_lines.tif.
#  Skipping....
# ('vector' var could not be deleted, likely doesn't exist)
# ('geom' var could not be deleted, likely doesn't exist)
# ('rasterized' var could not be deleted, likely doesn't exist)
# ('src' var could not be deleted, likely doesn't exist)
# Polyrast End 2025-03-04 17:13:13
# Polyras Code block run in 0:00:00.025451
#
# Polyrast Start 2025-03-04 17:13:13
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/hotosm_gbr_airports_points_gpkg.tif.
#  Processing....
# Read ref raster Start 2025-03-04 17:13:13
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/UKCEH_LC_2023_10m.tif
# Read poly Start 2025-03-04 17:13:13
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/raw/Airports/hotosm_gbr_airports_points_gpkg.gpkg
# Rasterize poly Start 2025-03-04 17:13:15
# Writing rasterized poly to file Start 2025-03-04 17:13:23
# Polyrast End 2025-03-04 17:14:05
# Polyras Code block run in 0:00:51.510520
#
# Polyrast Start 2025-03-04 17:14:05
# File already exists: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/Study_area_basedOn_UK_BFC_EPSG27700.tif.
#  Skipping....
# ('vector' var could not be deleted, likely doesn't exist)
# ('geom' var could not be deleted, likely doesn't exist)
# ('rasterized' var could not be deleted, likely doesn't exist)
# ('src' var could not be deleted, likely doesn't exist)
# Polyrast End 2025-03-04 17:14:05
# Polyras Code block run in 0:00:00.042251
#
# Polyrast Start 2025-03-04 17:14:05
# File already exists: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/OS_open_rivers_lines.tif.
#  Skipping....
# ('vector' var could not be deleted, likely doesn't exist)
# ('geom' var could not be deleted, likely doesn't exist)
# ('rasterized' var could not be deleted, likely doesn't exist)
# ('src' var could not be deleted, likely doesn't exist)
# Polyrast End 2025-03-04 17:14:05
# Polyras Code block run in 0:00:00.033599
#
# Polyrast Start 2025-03-04 17:14:05
# File already exists: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/Heritage_Listed_Buildings_poly.tif.
#  Skipping....
# ('vector' var could not be deleted, likely doesn't exist)
# ('geom' var could not be deleted, likely doesn't exist)
# ('rasterized' var could not be deleted, likely doesn't exist)
# ('src' var could not be deleted, likely doesn't exist)
# Polyrast End 2025-03-04 17:14:05
# Polyras Code block run in 0:00:00.019449
#
# Polyrast Start 2025-03-04 17:14:05
# File already exists: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/Heritage_Listed_Buildings_points.tif.
#  Skipping....
# ('vector' var could not be deleted, likely doesn't exist)
# ('geom' var could not be deleted, likely doesn't exist)
# ('rasterized' var could not be deleted, likely doesn't exist)
# ('src' var could not be deleted, likely doesn't exist)
# Polyrast End 2025-03-04 17:14:05
# Polyras Code block run in 0:00:00.030218
#
# Polyrast Start 2025-03-04 17:14:05
# File already exists: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/Heritage_Parks_Gardens.tif.
#  Skipping....
# ('vector' var could not be deleted, likely doesn't exist)
# ('geom' var could not be deleted, likely doesn't exist)
# ('rasterized' var could not be deleted, likely doesn't exist)
# ('src' var could not be deleted, likely doesn't exist)
# Polyrast End 2025-03-04 17:14:05
# Polyras Code block run in 0:00:00.026736
#
# Polyrast Start 2025-03-04 17:14:05
# File already exists: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/Heritage_Monuments.tif.
#  Skipping....
# ('vector' var could not be deleted, likely doesn't exist)
# ('geom' var could not be deleted, likely doesn't exist)
# ('rasterized' var could not be deleted, likely doesn't exist)
# ('src' var could not be deleted, likely doesn't exist)
# Polyrast End 2025-03-04 17:14:05
# Polyras Code block run in 0:00:00.023699
#
# Polyrast Start 2025-03-04 17:14:05
# File already exists: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/Heritage_WHS_Battlefields.tif.
#  Skipping....
# ('vector' var could not be deleted, likely doesn't exist)
# ('geom' var could not be deleted, likely doesn't exist)
# ('rasterized' var could not be deleted, likely doesn't exist)
# ('src' var could not be deleted, likely doesn't exist)
# Polyrast End 2025-03-04 17:14:05
# Polyras Code block run in 0:00:00.022114

# %%
# redo solar poly because some poly were omitted in previous run
raster_path = f'{preppedDat_path}Land Cover/UKCEH_LC_2023_10m.tif'
logpath = f'{interimFiles_path}polyrast/logs/Solar_poly_polyrast.txt'
poly_path = f'{preppedDat_path}Existing RE/global_solar_2020_poly_cropped.gpkg'
polyrast(poly_path, raster_path, logpath, all_touched=True)
# Out:
# Polyrast Start 2025-03-07 17:48:02
# File does not exist: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/global_solar_2020_poly_cropped.tif.
#  Processing....
# Read ref raster Start 2025-03-07 17:48:02
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/Land Cover/UKCEH_LC_2023_10m.tif
# Read poly Start 2025-03-07 17:48:03
#  from: C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/data/prepped_data/Existing RE/global_solar_2020_poly_cropped.gpkg
# Rasterize poly Start 2025-03-07 17:48:07
# Writing rasterized poly to file Start 2025-03-07 17:48:45
# Polyrast End 2025-03-07 17:50:15
# Polyras Code block run in 0:02:12.873854
# 'C:/Users/roro_/Documents/University/UG year 3/6SSG0610 IGS Independent Geographical Study/output/intermediate_files/polyrast/global_solar_2020_poly_cropped.tif'

# %% [markdown]
# Second rasterization of global_solar_2020_poly_cropped wroekd even worse than the first, none of the poly were rasterized! Doing it in QGIS. Will need to check other layers for major discrepancies.

# %% [markdown]
# #### Merge poly-points layers of the same class

# %% [markdown]
# ##### Existing Solar

# %%
write_path = f'{preppedDat_path}Existing RE/global_solar_2020_merged.tif'
path1 = f'{preppedDat_path}Existing RE/global_solar_2020_point_cropped.tif'
path2 = f'{preppedDat_path}Existing RE/global_solar_2020_poly_cropped.tif'

with rio.open(path1) as src_1:
    dask_ar_1 = da.from_array(src_1.read(1), chunks= 100)

with rio.open(path2) as src_2:
    dask_ar_2 = da.from_array(src_2.read(1), chunks= 100)

    # Merging 1-2
    logmsk = f'Merge 1-2\n Mask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logmsk)
    mask = dask_ar_1 > 0 # Make a boolean array out of non-null raster pixels
    logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logdifst)
    processed_data = da.where(mask, 1, dask_ar_2) #Pixels in mask set to 1        
    logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge 1-2 complete.'
    print(logdif)
    
    # Write result to file
    with rio.open(
        write_path, 'w',
        driver='GTiff',
        height=processed_data.shape[0],
        width=processed_data.shape[1],
        count=1,
        dtype=processed_data.dtype,
        crs=src_1.crs,
        transform=src_1.transform,
        compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

    logwri = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge final result written to file.'
    print(logwri)
# Out:
# Merge 1-2
#  Mask creation Start 2025-03-07 15:47:35
# Merge Start 2025-03-07 15:47:36
# 2025-03-07 15:47:41 - Merge 1-2 complete.
# 2025-03-07 15:59:22 - Merge final result written to file.

# %% [markdown]
# ##### Listed Buildings

# %%
write_path = f'{preppedDat_path}Heritage/Heritage_Listed_Buildings_merged.tif'
path1 = f'{preppedDat_path}Heritage/Heritage_Listed_Buildings_points.tif'
path2 = f'{preppedDat_path}Heritage/Heritage_Listed_Buildings_poly.tif'

with rio.open(path1) as src_1:
    dask_ar_1 = da.from_array(src_1.read(1), chunks= 100)

with rio.open(path2) as src_2:
    dask_ar_2 = da.from_array(src_2.read(1), chunks= 100)

    # Merging 1-2
    logmsk = f'Merge 1-2\n Mask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logmsk)
    mask = dask_ar_1 > 0 # Make a boolean array out of non-null raster pixels
    logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logdifst)
    processed_data = da.where(mask, 1, dask_ar_2) #Pixels in mask set to 1        
    logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge 1-2 complete.'
    print(logdif)
    
    # Write result to file
    with rio.open(
        write_path, 'w',
        driver='GTiff',
        height=processed_data.shape[0],
        width=processed_data.shape[1],
        count=1,
        dtype=processed_data.dtype,
        crs=src_1.crs,
        transform=src_1.transform,
        compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

    logwri = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge final result written to file.'
    print(logwri)
# Out:
# Merge 1-2
#  Mask creation Start 2025-03-07 16:00:33
# Merge Start 2025-03-07 16:00:33
# 2025-03-07 16:00:38 - Merge 1-2 complete.
# 2025-03-07 16:11:18 - Merge final result written to file.

# %% [markdown]
# ##### Water + Rivers

# %%
write_path = f'{preppedDat_path}Land Cover/Water_rivers_merged.tif'
path1 = f'{preppedDat_path}Land Cover/OS_open_rivers_lines.tif'
path2 = f'{preppedDat_path}Land Cover/UKCEH_10m_water.tif'

with rio.open(path1) as src_1:
    dask_ar_1 = da.from_array(src_1.read(1), chunks= 100)

with rio.open(path2) as src_2:
    dask_ar_2 = da.from_array(src_2.read(1), chunks= 100)

    # Merging 1-2
    logmsk = f'Merge 1-2\n Mask creation Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logmsk)
    mask = dask_ar_1 > 0 # Make a boolean array out of non-null raster pixels
    logdifst = f'Merge Start {datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'
    print(logdifst)
    processed_data = da.where(mask, 1, dask_ar_2) #Pixels in mask set to 1        
    logdif = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge 1-2 complete.'
    print(logdif)
    
    # Write result to file
    with rio.open(
        write_path, 'w',
        driver='GTiff',
        height=processed_data.shape[0],
        width=processed_data.shape[1],
        count=1,
        dtype=processed_data.dtype,
        crs=src_1.crs,
        transform=src_1.transform,
        compress='DEFLATE'
    ) as dst:
        dst.write(processed_data.compute(), 1)

    logwri = f'{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")} - Merge final result written to file.'
    print(logwri)
# Out:
# Merge 1-2
#  Mask creation Start 2025-03-07 18:29:55
# Merge Start 2025-03-07 18:29:56
# 2025-03-07 18:29:56 - Merge 1-2 complete.
# 2025-03-07 18:54:42 - Merge final result written to file.
